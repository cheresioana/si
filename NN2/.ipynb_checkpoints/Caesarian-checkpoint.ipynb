# %%
from torch.utils.data import Dataset, DataLoader
from torch import nn, from_numpy, optim
import numpy as np
#pandas- librărie pentru lucrul cu fișierele
import pandas as pd
import torch
import torch.nn as nn

# %%
# !pwd
df=pd.read_csv("caesarian.csv", error_bad_lines=False, engine='python')
# Out:
# /home/ioana/faculta/si/regresie/tema2

# %%
df.values
# Out:
# array([['38 } '],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None],
#        [None]], dtype=object)

# %%
#Dataset - o clasă din PyTorch foarte utilă gestionării seturilor de date
class DiabetesDataset(Dataset):
    """ Diabetes dataset."""
    # Initialize your data, download, etc.
    def __init__(self):
        #Citim setul de date
        df=pd.read_csv("caesarian.csv",header=None, dtype=np.float32)
        xy = torch.from_numpy(df.values)
        self.len = xy.shape[0]
        #Vom folosi ca input toate valorile mai puțin ultima coloană
        self.x_data = xy[:, 0:-1]
        #Vom folosi ca output ultima coloană
        self.y_data = xy[:, [-1]]

    def __getitem__(self, index):
        return self.x_data[index], self.y_data[index]

    def __len__(self):
        return self.len

# %%
dataset = DiabetesDataset()
#DataLoader - un utilitar ce ne ajută să împărțim setul de date pe batch-uri și astfel să facem antrenare în mod Mini-Batch
train_loader = DataLoader(dataset=dataset,
                          batch_size=32,
                          shuffle=True,
                          num_workers=1)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-10-6dd0cdc171b9> in <module>
# ----> 1 dataset = DiabetesDataset()
#       2 #DataLoader - un utilitar ce ne ajută să împărțim setul de date pe batch-uri și astfel să facem antrenare în mod Mini-Batch
#       3 train_loader = DataLoader(dataset=dataset,
#       4                           batch_size=32,
#       5                           shuffle=True,
#
# <ipython-input-9-5ae6b4696336> in __init__(self)
#       5     def __init__(self):
#       6         #Citim setul de date
# ----> 7         df=pd.read_csv("caesarian.csv",header=None, dtype=np.float32)
#       8         xy = torch.from_numpy(df.values)
#       9         self.len = xy.shape[0]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     461
#     462     try:
# --> 463         data = parser.read(nrows)
#     464     finally:
#     465         parser.close()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1152     def read(self, nrows=None):
#    1153         nrows = _validate_integer("nrows", nrows)
# -> 1154         ret = self._engine.read(nrows)
#    1155
#    1156         # May alter columns / col_dict
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2057     def read(self, nrows=None):
#    2058         try:
# -> 2059             data = self._reader.read(nrows)
#    2060         except StopIteration:
#    2061             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 6, saw 22

# %%
dataset[0]
# Out:
# (tensor([-0.2941,  0.4874,  0.1803, -0.2929,  0.0000,  0.0015, -0.5312, -0.0333]),
#  tensor([0.]))

# %%
class Model(nn.Module):

    def __init__(self):
        """
        In the constructor we instantiate two nn.Linear module
        """
        super(Model, self).__init__()
        self.l1 = nn.Linear(8, 6)
        self.l2 = nn.Linear(6, 4)
        self.l3 = nn.Linear(4, 1)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        """
        In the forward function we accept a Variable of input data and we must return
        a Variable of output data. We can use Modules defined in the constructor as
        well as arbitrary operators on Variables.
        """
        out1 = self.sigmoid(self.l1(x))
        out2 = self.sigmoid(self.l2(out1))
        y_pred = self.sigmoid(self.l3(out2))
        return y_pred

# %%
model=Model()

# %%
criterion = nn.BCELoss(reduction='sum')
optimizer = optim.SGD(model.parameters(), lr=0.1)

# %%
# Training loop
for epoch in range(200):
  for i, data in enumerate(train_loader, 0):
      # get the inputs
      inputs, labels = data

      # Forward pass: Compute predicted y by passing x to the model
      y_pred = model(inputs)

      # Compute and print loss
      loss = criterion(y_pred, labels)
      print(f'Epoch {epoch + 1} | Batch: {i+1} | Loss: {loss.item():.4f}')

      # Zero gradients, perform a backward pass, and update the weights.
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
# Out:
# Epoch 1 | Batch: 1 | Loss: 23.8410
# Epoch 1 | Batch: 2 | Loss: 19.3455
# Epoch 1 | Batch: 3 | Loss: 18.1396
# Epoch 1 | Batch: 4 | Loss: 18.0307
# Epoch 1 | Batch: 5 | Loss: 23.4817
# Epoch 1 | Batch: 6 | Loss: 21.0823
# Epoch 1 | Batch: 7 | Loss: 32.1111
# Epoch 1 | Batch: 8 | Loss: 27.0057
# Epoch 1 | Batch: 9 | Loss: 21.9954
# Epoch 1 | Batch: 10 | Loss: 20.8002
# Epoch 1 | Batch: 11 | Loss: 23.1176
# Epoch 1 | Batch: 12 | Loss: 19.3600
# Epoch 1 | Batch: 13 | Loss: 24.0992
# Epoch 1 | Batch: 14 | Loss: 20.0972
# Epoch 1 | Batch: 15 | Loss: 23.0791
# Epoch 1 | Batch: 16 | Loss: 20.6869
# Epoch 1 | Batch: 17 | Loss: 20.2235
# Epoch 1 | Batch: 18 | Loss: 23.1363
# Epoch 1 | Batch: 19 | Loss: 21.0511
# Epoch 1 | Batch: 20 | Loss: 22.3285
# Epoch 1 | Batch: 21 | Loss: 20.8834
# Epoch 1 | Batch: 22 | Loss: 21.2542
# Epoch 1 | Batch: 23 | Loss: 19.1402
# Epoch 1 | Batch: 24 | Loss: 14.2738
# Epoch 2 | Batch: 1 | Loss: 16.2750
# Epoch 2 | Batch: 2 | Loss: 22.2693
# Epoch 2 | Batch: 3 | Loss: 22.0674
# Epoch 2 | Batch: 4 | Loss: 19.3630
# Epoch 2 | Batch: 5 | Loss: 14.4209
# Epoch 2 | Batch: 6 | Loss: 24.6987
# Epoch 2 | Batch: 7 | Loss: 21.8810
# Epoch 2 | Batch: 8 | Loss: 22.3772
# Epoch 2 | Batch: 9 | Loss: 21.5387
# Epoch 2 | Batch: 10 | Loss: 19.8675
# Epoch 2 | Batch: 11 | Loss: 23.0235
# Epoch 2 | Batch: 12 | Loss: 21.6712
# Epoch 2 | Batch: 13 | Loss: 21.2283
# Epoch 2 | Batch: 14 | Loss: 20.1395
# Epoch 2 | Batch: 15 | Loss: 19.8687
# Epoch 2 | Batch: 16 | Loss: 19.8658
# Epoch 2 | Batch: 17 | Loss: 19.8698
# Epoch 2 | Batch: 18 | Loss: 23.0197
# Epoch 2 | Batch: 19 | Loss: 20.6062
# Epoch 2 | Batch: 20 | Loss: 18.9968
# Epoch 2 | Batch: 21 | Loss: 24.5987
# Epoch 2 | Batch: 22 | Loss: 21.3253
# Epoch 2 | Batch: 23 | Loss: 23.6764
# Epoch 2 | Batch: 24 | Loss: 15.7797
# Epoch 3 | Batch: 1 | Loss: 20.7685
# Epoch 3 | Batch: 2 | Loss: 18.1219
# Epoch 3 | Batch: 3 | Loss: 25.3865
# Epoch 3 | Batch: 4 | Loss: 21.5394
# Epoch 3 | Batch: 5 | Loss: 18.6494
# Epoch 3 | Batch: 6 | Loss: 16.8380
# Epoch 3 | Batch: 7 | Loss: 25.4556
# Epoch 3 | Batch: 8 | Loss: 21.9775
# Epoch 3 | Batch: 9 | Loss: 21.1509
# Epoch 3 | Batch: 10 | Loss: 22.4298
# Epoch 3 | Batch: 11 | Loss: 22.4720
# Epoch 3 | Batch: 12 | Loss: 22.1442
# Epoch 3 | Batch: 13 | Loss: 20.1198
# Epoch 3 | Batch: 14 | Loss: 17.2594
# Epoch 3 | Batch: 15 | Loss: 25.0316
# Epoch 3 | Batch: 16 | Loss: 23.0921
# Epoch 3 | Batch: 17 | Loss: 22.8247
# Epoch 3 | Batch: 18 | Loss: 20.5942
# Epoch 3 | Batch: 19 | Loss: 22.5531
# Epoch 3 | Batch: 20 | Loss: 20.2121
# Epoch 3 | Batch: 21 | Loss: 18.0227
# Epoch 3 | Batch: 22 | Loss: 19.0392
# Epoch 3 | Batch: 23 | Loss: 20.9266
# Epoch 3 | Batch: 24 | Loss: 12.7402
# Epoch 4 | Batch: 1 | Loss: 26.1499
# Epoch 4 | Batch: 2 | Loss: 21.7557
# Epoch 4 | Batch: 3 | Loss: 19.7054
# Epoch 4 | Batch: 4 | Loss: 20.7352
# Epoch 4 | Batch: 5 | Loss: 19.8724
# Epoch 4 | Batch: 6 | Loss: 22.9339
# Epoch 4 | Batch: 7 | Loss: 20.6535
# Epoch 4 | Batch: 8 | Loss: 22.0595
# Epoch 4 | Batch: 9 | Loss: 19.4887
# Epoch 4 | Batch: 10 | Loss: 16.0546
# Epoch 4 | Batch: 11 | Loss: 23.3157
# Epoch 4 | Batch: 12 | Loss: 21.9232
# Epoch 4 | Batch: 13 | Loss: 20.7479
# Epoch 4 | Batch: 14 | Loss: 21.1863
# Epoch 4 | Batch: 15 | Loss: 21.6548
# Epoch 4 | Batch: 16 | Loss: 19.5969
# Epoch 4 | Batch: 17 | Loss: 20.9146
# Epoch 4 | Batch: 18 | Loss: 19.1424
# Epoch 4 | Batch: 19 | Loss: 20.7763
# Epoch 4 | Batch: 20 | Loss: 19.8705
# Epoch 4 | Batch: 21 | Loss: 20.6040
# Epoch 4 | Batch: 22 | Loss: 20.5433
# Epoch 4 | Batch: 23 | Loss: 21.8465
# Epoch 4 | Batch: 24 | Loss: 15.3446
# Epoch 5 | Batch: 1 | Loss: 18.9821
# Epoch 5 | Batch: 2 | Loss: 24.4779
# Epoch 5 | Batch: 3 | Loss: 20.4110
# Epoch 5 | Batch: 4 | Loss: 16.8980
# Epoch 5 | Batch: 5 | Loss: 15.5087
# Epoch 5 | Batch: 6 | Loss: 20.9677
# Epoch 5 | Batch: 7 | Loss: 20.8479
# Epoch 5 | Batch: 8 | Loss: 21.2250
# Epoch 5 | Batch: 9 | Loss: 19.4845
# Epoch 5 | Batch: 10 | Loss: 24.1386
# Epoch 5 | Batch: 11 | Loss: 20.5290
# Epoch 5 | Batch: 12 | Loss: 17.0256
# Epoch 5 | Batch: 13 | Loss: 19.1069
# Epoch 5 | Batch: 14 | Loss: 21.9388
# Epoch 5 | Batch: 15 | Loss: 21.7104
# Epoch 5 | Batch: 16 | Loss: 23.1942
# Epoch 5 | Batch: 17 | Loss: 22.5252
# Epoch 5 | Batch: 18 | Loss: 23.3747
# Epoch 5 | Batch: 19 | Loss: 21.8245
# Epoch 5 | Batch: 20 | Loss: 21.7125
# Epoch 5 | Batch: 21 | Loss: 19.1194
# Epoch 5 | Batch: 22 | Loss: 29.8075
# Epoch 5 | Batch: 23 | Loss: 22.6352
# Epoch 5 | Batch: 24 | Loss: 14.8454
# Epoch 6 | Batch: 1 | Loss: 21.1619
# Epoch 6 | Batch: 2 | Loss: 20.5013
# Epoch 6 | Batch: 3 | Loss: 21.7644
# Epoch 6 | Batch: 4 | Loss: 21.9230
# Epoch 6 | Batch: 5 | Loss: 21.2392
# Epoch 6 | Batch: 6 | Loss: 19.0524
# Epoch 6 | Batch: 7 | Loss: 18.8051
# Epoch 6 | Batch: 8 | Loss: 22.7287
# Epoch 6 | Batch: 9 | Loss: 19.1529
# Epoch 6 | Batch: 10 | Loss: 23.7688
# Epoch 6 | Batch: 11 | Loss: 20.7767
# Epoch 6 | Batch: 12 | Loss: 19.8337
# Epoch 6 | Batch: 13 | Loss: 23.4303
# Epoch 6 | Batch: 14 | Loss: 21.5714
# Epoch 6 | Batch: 15 | Loss: 19.6650
# Epoch 6 | Batch: 16 | Loss: 18.9327
# Epoch 6 | Batch: 17 | Loss: 18.8484
# Epoch 6 | Batch: 18 | Loss: 19.7870
# Epoch 6 | Batch: 19 | Loss: 22.1600
# Epoch 6 | Batch: 20 | Loss: 20.5367
# Epoch 6 | Batch: 21 | Loss: 22.7645
# Epoch 6 | Batch: 22 | Loss: 20.9677
# Epoch 6 | Batch: 23 | Loss: 16.8852
# Epoch 6 | Batch: 24 | Loss: 16.9184
# Epoch 7 | Batch: 1 | Loss: 18.9208
# Epoch 7 | Batch: 2 | Loss: 20.5149
# Epoch 7 | Batch: 3 | Loss: 18.2192
# Epoch 7 | Batch: 4 | Loss: 16.7292
# Epoch 7 | Batch: 5 | Loss: 20.2960
# Epoch 7 | Batch: 6 | Loss: 19.6094
# Epoch 7 | Batch: 7 | Loss: 21.1674
# Epoch 7 | Batch: 8 | Loss: 21.1960
# Epoch 7 | Batch: 9 | Loss: 21.7299
# Epoch 7 | Batch: 10 | Loss: 20.3075
# Epoch 7 | Batch: 11 | Loss: 26.4113
# Epoch 7 | Batch: 12 | Loss: 23.1932
# Epoch 7 | Batch: 13 | Loss: 21.1039
# Epoch 7 | Batch: 14 | Loss: 21.7682
# Epoch 7 | Batch: 15 | Loss: 21.8713
# Epoch 7 | Batch: 16 | Loss: 21.5901
# Epoch 7 | Batch: 17 | Loss: 16.8988
# Epoch 7 | Batch: 18 | Loss: 27.0895
# Epoch 7 | Batch: 19 | Loss: 21.1847
# Epoch 7 | Batch: 20 | Loss: 23.6046
# Epoch 7 | Batch: 21 | Loss: 20.9708
# Epoch 7 | Batch: 22 | Loss: 20.8215
# Epoch 7 | Batch: 23 | Loss: 18.1596
# Epoch 7 | Batch: 24 | Loss: 11.5641
# Epoch 8 | Batch: 1 | Loss: 19.0060
# Epoch 8 | Batch: 2 | Loss: 19.2376
# Epoch 8 | Batch: 3 | Loss: 19.4170
# Epoch 8 | Batch: 4 | Loss: 17.8463
# Epoch 8 | Batch: 5 | Loss: 24.2905
# Epoch 8 | Batch: 6 | Loss: 20.4417
# Epoch 8 | Batch: 7 | Loss: 19.3649
# Epoch 8 | Batch: 8 | Loss: 19.3155
# Epoch 8 | Batch: 9 | Loss: 20.9713
# Epoch 8 | Batch: 10 | Loss: 22.7397
# Epoch 8 | Batch: 11 | Loss: 23.0956
# Epoch 8 | Batch: 12 | Loss: 17.3330
# Epoch 8 | Batch: 13 | Loss: 17.0621
# Epoch 8 | Batch: 14 | Loss: 20.7933
# Epoch 8 | Batch: 15 | Loss: 22.4440
# Epoch 8 | Batch: 16 | Loss: 21.9333
# Epoch 8 | Batch: 17 | Loss: 18.1117
# Epoch 8 | Batch: 18 | Loss: 19.5564
# Epoch 8 | Batch: 19 | Loss: 18.2807
# Epoch 8 | Batch: 20 | Loss: 16.2947
# Epoch 8 | Batch: 21 | Loss: 18.4405
# Epoch 8 | Batch: 22 | Loss: 18.8355
# Epoch 8 | Batch: 23 | Loss: 20.8840
# Epoch 8 | Batch: 24 | Loss: 14.9883
# Epoch 9 | Batch: 1 | Loss: 19.7156
# Epoch 9 | Batch: 2 | Loss: 21.1881
# Epoch 9 | Batch: 3 | Loss: 13.5533
# Epoch 9 | Batch: 4 | Loss: 32.9551
# Epoch 9 | Batch: 5 | Loss: 27.5822
# Epoch 9 | Batch: 6 | Loss: 27.1647
# Epoch 9 | Batch: 7 | Loss: 20.4446
# Epoch 9 | Batch: 8 | Loss: 19.3828
# Epoch 9 | Batch: 9 | Loss: 18.7323
# Epoch 9 | Batch: 10 | Loss: 18.0284
# Epoch 9 | Batch: 11 | Loss: 15.5057
# Epoch 9 | Batch: 12 | Loss: 20.3695
# Epoch 9 | Batch: 13 | Loss: 16.8199
# Epoch 9 | Batch: 14 | Loss: 18.1235
# Epoch 9 | Batch: 15 | Loss: 17.0079
# Epoch 9 | Batch: 16 | Loss: 17.0996
# Epoch 9 | Batch: 17 | Loss: 17.2246
# Epoch 9 | Batch: 18 | Loss: 16.1787
# Epoch 9 | Batch: 19 | Loss: 20.0895
# Epoch 9 | Batch: 20 | Loss: 17.6355
# Epoch 9 | Batch: 21 | Loss: 15.4195
# Epoch 9 | Batch: 22 | Loss: 20.6508
# Epoch 9 | Batch: 23 | Loss: 17.7826
# Epoch 9 | Batch: 24 | Loss: 12.0155
# Epoch 10 | Batch: 1 | Loss: 15.5990
# Epoch 10 | Batch: 2 | Loss: 14.6304
# Epoch 10 | Batch: 3 | Loss: 14.8277
# Epoch 10 | Batch: 4 | Loss: 15.4661
# Epoch 10 | Batch: 5 | Loss: 24.0855
# Epoch 10 | Batch: 6 | Loss: 22.1508
# Epoch 10 | Batch: 7 | Loss: 14.3269
# Epoch 10 | Batch: 8 | Loss: 14.9718
# Epoch 10 | Batch: 9 | Loss: 19.5270
# Epoch 10 | Batch: 10 | Loss: 20.6554
# Epoch 10 | Batch: 11 | Loss: 15.5234
# Epoch 10 | Batch: 12 | Loss: 15.7848
# Epoch 10 | Batch: 13 | Loss: 14.6721
# Epoch 10 | Batch: 14 | Loss: 14.3261
# Epoch 10 | Batch: 15 | Loss: 13.8412
# Epoch 10 | Batch: 16 | Loss: 26.6155
# Epoch 10 | Batch: 17 | Loss: 19.8121
# Epoch 10 | Batch: 18 | Loss: 20.8472
# Epoch 10 | Batch: 19 | Loss: 14.7605
# Epoch 10 | Batch: 20 | Loss: 16.3600
# Epoch 10 | Batch: 21 | Loss: 15.0766
# Epoch 10 | Batch: 22 | Loss: 21.0136
# Epoch 10 | Batch: 23 | Loss: 19.5665
# Epoch 10 | Batch: 24 | Loss: 10.7846
# Epoch 11 | Batch: 1 | Loss: 14.6221
# Epoch 11 | Batch: 2 | Loss: 13.5416
# Epoch 11 | Batch: 3 | Loss: 19.3389
# Epoch 11 | Batch: 4 | Loss: 23.3250
# Epoch 11 | Batch: 5 | Loss: 15.8720
# Epoch 11 | Batch: 6 | Loss: 15.6428
# Epoch 11 | Batch: 7 | Loss: 16.0863
# Epoch 11 | Batch: 8 | Loss: 14.2737
# Epoch 11 | Batch: 9 | Loss: 17.3725
# Epoch 11 | Batch: 10 | Loss: 13.9953
# Epoch 11 | Batch: 11 | Loss: 16.4442
# Epoch 11 | Batch: 12 | Loss: 16.8494
# Epoch 11 | Batch: 13 | Loss: 15.9745
# Epoch 11 | Batch: 14 | Loss: 20.2307
# Epoch 11 | Batch: 15 | Loss: 18.9730
# Epoch 11 | Batch: 16 | Loss: 13.9542
# Epoch 11 | Batch: 17 | Loss: 13.5657
# Epoch 11 | Batch: 18 | Loss: 16.8125
# Epoch 11 | Batch: 19 | Loss: 23.1839
# Epoch 11 | Batch: 20 | Loss: 22.4337
# Epoch 11 | Batch: 21 | Loss: 13.7493
# Epoch 11 | Batch: 22 | Loss: 13.2741
# Epoch 11 | Batch: 23 | Loss: 13.1559
# Epoch 11 | Batch: 24 | Loss: 9.5788
# Epoch 12 | Batch: 1 | Loss: 17.1499
# Epoch 12 | Batch: 2 | Loss: 13.9999
# Epoch 12 | Batch: 3 | Loss: 21.9069
# Epoch 12 | Batch: 4 | Loss: 21.1537
# Epoch 12 | Batch: 5 | Loss: 20.3583
# Epoch 12 | Batch: 6 | Loss: 17.2436
# Epoch 12 | Batch: 7 | Loss: 14.2312
# Epoch 12 | Batch: 8 | Loss: 14.0391
# Epoch 12 | Batch: 9 | Loss: 13.7198
# Epoch 12 | Batch: 10 | Loss: 13.1904
# Epoch 12 | Batch: 11 | Loss: 22.4638
# Epoch 12 | Batch: 12 | Loss: 15.5170
# Epoch 12 | Batch: 13 | Loss: 13.3276
# Epoch 12 | Batch: 14 | Loss: 11.9981
# Epoch 12 | Batch: 15 | Loss: 15.0327
# Epoch 12 | Batch: 16 | Loss: 16.4305
# Epoch 12 | Batch: 17 | Loss: 16.7671
# Epoch 12 | Batch: 18 | Loss: 15.6044
# Epoch 12 | Batch: 19 | Loss: 15.0300
# Epoch 12 | Batch: 20 | Loss: 17.8416
# Epoch 12 | Batch: 21 | Loss: 16.7391
# Epoch 12 | Batch: 22 | Loss: 12.5714
# Epoch 12 | Batch: 23 | Loss: 19.1012
# Epoch 12 | Batch: 24 | Loss: 10.6341
# Epoch 13 | Batch: 1 | Loss: 12.1444
# Epoch 13 | Batch: 2 | Loss: 13.1156
# Epoch 13 | Batch: 3 | Loss: 15.9445
# Epoch 13 | Batch: 4 | Loss: 15.0981
# Epoch 13 | Batch: 5 | Loss: 23.7159
# Epoch 13 | Batch: 6 | Loss: 19.4705
# Epoch 13 | Batch: 7 | Loss: 15.4604
# Epoch 13 | Batch: 8 | Loss: 14.8648
# Epoch 13 | Batch: 9 | Loss: 13.4254
# Epoch 13 | Batch: 10 | Loss: 10.9909
# Epoch 13 | Batch: 11 | Loss: 12.4213
# Epoch 13 | Batch: 12 | Loss: 10.9844
# Epoch 13 | Batch: 13 | Loss: 22.4749
# Epoch 13 | Batch: 14 | Loss: 19.5760
# Epoch 13 | Batch: 15 | Loss: 16.1763
# Epoch 13 | Batch: 16 | Loss: 16.9385
# Epoch 13 | Batch: 17 | Loss: 14.6996
# Epoch 13 | Batch: 18 | Loss: 16.7070
# Epoch 13 | Batch: 19 | Loss: 15.0243
# Epoch 13 | Batch: 20 | Loss: 14.2097
# Epoch 13 | Batch: 21 | Loss: 15.1813
# Epoch 13 | Batch: 22 | Loss: 16.1394
# Epoch 13 | Batch: 23 | Loss: 14.5162
# Epoch 13 | Batch: 24 | Loss: 18.5712
# Epoch 14 | Batch: 1 | Loss: 18.0424
# Epoch 14 | Batch: 2 | Loss: 13.2804
# Epoch 14 | Batch: 3 | Loss: 17.6223
# Epoch 14 | Batch: 4 | Loss: 17.0213
# Epoch 14 | Batch: 5 | Loss: 10.0760
# Epoch 14 | Batch: 6 | Loss: 21.3763
# Epoch 14 | Batch: 7 | Loss: 19.0064
# Epoch 14 | Batch: 8 | Loss: 21.1132
# Epoch 14 | Batch: 9 | Loss: 18.5226
# Epoch 14 | Batch: 10 | Loss: 12.2335
# Epoch 14 | Batch: 11 | Loss: 17.1377
# Epoch 14 | Batch: 12 | Loss: 19.7736
# Epoch 14 | Batch: 13 | Loss: 14.0005
# Epoch 14 | Batch: 14 | Loss: 15.8184
# Epoch 14 | Batch: 15 | Loss: 16.3095
# Epoch 14 | Batch: 16 | Loss: 15.5697
# Epoch 14 | Batch: 17 | Loss: 14.2640
# Epoch 14 | Batch: 18 | Loss: 5.4319
# Epoch 14 | Batch: 19 | Loss: 28.1482
# Epoch 14 | Batch: 20 | Loss: 19.7136
# Epoch 14 | Batch: 21 | Loss: 15.9578
# Epoch 14 | Batch: 22 | Loss: 19.5621
# Epoch 14 | Batch: 23 | Loss: 13.1188
# Epoch 14 | Batch: 24 | Loss: 6.7669
# Epoch 15 | Batch: 1 | Loss: 15.5405
# Epoch 15 | Batch: 2 | Loss: 13.9977
# Epoch 15 | Batch: 3 | Loss: 10.2131
# Epoch 15 | Batch: 4 | Loss: 17.5344
# Epoch 15 | Batch: 5 | Loss: 12.4624
# Epoch 15 | Batch: 6 | Loss: 12.3791
# Epoch 15 | Batch: 7 | Loss: 25.3688
# Epoch 15 | Batch: 8 | Loss: 21.9629
# Epoch 15 | Batch: 9 | Loss: 19.1119
# Epoch 15 | Batch: 10 | Loss: 19.5938
# Epoch 15 | Batch: 11 | Loss: 15.6925
# Epoch 15 | Batch: 12 | Loss: 10.9900
# Epoch 15 | Batch: 13 | Loss: 12.6252
# Epoch 15 | Batch: 14 | Loss: 24.3988
# Epoch 15 | Batch: 15 | Loss: 16.7162
# Epoch 15 | Batch: 16 | Loss: 18.0761
# Epoch 15 | Batch: 17 | Loss: 15.6565
# Epoch 15 | Batch: 18 | Loss: 13.2714
# Epoch 15 | Batch: 19 | Loss: 14.0711
# Epoch 15 | Batch: 20 | Loss: 16.3753
# Epoch 15 | Batch: 21 | Loss: 12.8558
# Epoch 15 | Batch: 22 | Loss: 17.2151
# Epoch 15 | Batch: 23 | Loss: 17.6519
# Epoch 15 | Batch: 24 | Loss: 11.8820
# Epoch 16 | Batch: 1 | Loss: 19.6215
# Epoch 16 | Batch: 2 | Loss: 13.0785
# Epoch 16 | Batch: 3 | Loss: 13.4308
# Epoch 16 | Batch: 4 | Loss: 11.0324
# Epoch 16 | Batch: 5 | Loss: 13.5904
# Epoch 16 | Batch: 6 | Loss: 22.9407
# Epoch 16 | Batch: 7 | Loss: 16.2183
# Epoch 16 | Batch: 8 | Loss: 13.5307
# Epoch 16 | Batch: 9 | Loss: 20.5952
# Epoch 16 | Batch: 10 | Loss: 16.2887
# Epoch 16 | Batch: 11 | Loss: 16.5098
# Epoch 16 | Batch: 12 | Loss: 14.9664
# Epoch 16 | Batch: 13 | Loss: 17.8168
# Epoch 16 | Batch: 14 | Loss: 18.0466
# Epoch 16 | Batch: 15 | Loss: 16.5976
# Epoch 16 | Batch: 16 | Loss: 13.3674
# Epoch 16 | Batch: 17 | Loss: 10.8530
# Epoch 16 | Batch: 18 | Loss: 17.0195
# Epoch 16 | Batch: 19 | Loss: 11.3255
# Epoch 16 | Batch: 20 | Loss: 20.9849
# Epoch 16 | Batch: 21 | Loss: 15.6971
# Epoch 16 | Batch: 22 | Loss: 13.3379
# Epoch 16 | Batch: 23 | Loss: 12.5664
# Epoch 16 | Batch: 24 | Loss: 10.5734
# Epoch 17 | Batch: 1 | Loss: 14.3149
# Epoch 17 | Batch: 2 | Loss: 12.7028
# Epoch 17 | Batch: 3 | Loss: 11.5132
# Epoch 17 | Batch: 4 | Loss: 12.4997
# Epoch 17 | Batch: 5 | Loss: 18.4597
# Epoch 17 | Batch: 6 | Loss: 12.1445
# Epoch 17 | Batch: 7 | Loss: 14.6059
# Epoch 17 | Batch: 8 | Loss: 13.1420
# Epoch 17 | Batch: 9 | Loss: 14.5418
# Epoch 17 | Batch: 10 | Loss: 15.3780
# Epoch 17 | Batch: 11 | Loss: 18.9470
# Epoch 17 | Batch: 12 | Loss: 24.2932
# Epoch 17 | Batch: 13 | Loss: 18.8163
# Epoch 17 | Batch: 14 | Loss: 20.7282
# Epoch 17 | Batch: 15 | Loss: 22.6761
# Epoch 17 | Batch: 16 | Loss: 19.3293
# Epoch 17 | Batch: 17 | Loss: 15.2789
# Epoch 17 | Batch: 18 | Loss: 11.7289
# Epoch 17 | Batch: 19 | Loss: 23.0390
# Epoch 17 | Batch: 20 | Loss: 21.2558
# Epoch 17 | Batch: 21 | Loss: 12.7450
# Epoch 17 | Batch: 22 | Loss: 15.6256
# Epoch 17 | Batch: 23 | Loss: 16.7319
# Epoch 17 | Batch: 24 | Loss: 9.5786
# Epoch 18 | Batch: 1 | Loss: 13.8331
# Epoch 18 | Batch: 2 | Loss: 17.7404
# Epoch 18 | Batch: 3 | Loss: 12.3215
# Epoch 18 | Batch: 4 | Loss: 16.9061
# Epoch 18 | Batch: 5 | Loss: 15.1860
# Epoch 18 | Batch: 6 | Loss: 11.9719
# Epoch 18 | Batch: 7 | Loss: 9.2228
# Epoch 18 | Batch: 8 | Loss: 8.2892
# Epoch 18 | Batch: 9 | Loss: 19.4112
# Epoch 18 | Batch: 10 | Loss: 18.0651
# Epoch 18 | Batch: 11 | Loss: 12.7514
# Epoch 18 | Batch: 12 | Loss: 24.4397
# Epoch 18 | Batch: 13 | Loss: 21.7250
# Epoch 18 | Batch: 14 | Loss: 15.7123
# Epoch 18 | Batch: 15 | Loss: 18.2759
# Epoch 18 | Batch: 16 | Loss: 20.3914
# Epoch 18 | Batch: 17 | Loss: 17.5841
# Epoch 18 | Batch: 18 | Loss: 21.9208
# Epoch 18 | Batch: 19 | Loss: 19.9004
# Epoch 18 | Batch: 20 | Loss: 20.2176
# Epoch 18 | Batch: 21 | Loss: 15.7273
# Epoch 18 | Batch: 22 | Loss: 14.5419
# Epoch 18 | Batch: 23 | Loss: 16.0529
# Epoch 18 | Batch: 24 | Loss: 9.7792
# Epoch 19 | Batch: 1 | Loss: 16.4120
# Epoch 19 | Batch: 2 | Loss: 15.8900
# Epoch 19 | Batch: 3 | Loss: 23.2852
# Epoch 19 | Batch: 4 | Loss: 20.3542
# Epoch 19 | Batch: 5 | Loss: 16.4999
# Epoch 19 | Batch: 6 | Loss: 16.7831
# Epoch 19 | Batch: 7 | Loss: 20.7366
# Epoch 19 | Batch: 8 | Loss: 9.8726
# Epoch 19 | Batch: 9 | Loss: 12.6798
# Epoch 19 | Batch: 10 | Loss: 14.5300
# Epoch 19 | Batch: 11 | Loss: 17.0149
# Epoch 19 | Batch: 12 | Loss: 17.7423
# Epoch 19 | Batch: 13 | Loss: 10.6079
# Epoch 19 | Batch: 14 | Loss: 14.0525
# Epoch 19 | Batch: 15 | Loss: 21.0729
# Epoch 19 | Batch: 16 | Loss: 18.2805
# Epoch 19 | Batch: 17 | Loss: 14.0198
# Epoch 19 | Batch: 18 | Loss: 12.6923
# Epoch 19 | Batch: 19 | Loss: 15.4276
# Epoch 19 | Batch: 20 | Loss: 17.8069
# Epoch 19 | Batch: 21 | Loss: 18.3296
# Epoch 19 | Batch: 22 | Loss: 12.2643
# Epoch 19 | Batch: 23 | Loss: 16.7139
# Epoch 19 | Batch: 24 | Loss: 15.9878
# Epoch 20 | Batch: 1 | Loss: 23.6256
# Epoch 20 | Batch: 2 | Loss: 13.1536
# Epoch 20 | Batch: 3 | Loss: 18.4190
# Epoch 20 | Batch: 4 | Loss: 14.9817
# Epoch 20 | Batch: 5 | Loss: 15.4244
# Epoch 20 | Batch: 6 | Loss: 11.0092
# Epoch 20 | Batch: 7 | Loss: 15.2923
# Epoch 20 | Batch: 8 | Loss: 16.2224
# Epoch 20 | Batch: 9 | Loss: 12.4736
# Epoch 20 | Batch: 10 | Loss: 16.9744
# Epoch 20 | Batch: 11 | Loss: 14.4848
# Epoch 20 | Batch: 12 | Loss: 22.1538
# Epoch 20 | Batch: 13 | Loss: 22.3193
# Epoch 20 | Batch: 14 | Loss: 16.1162
# Epoch 20 | Batch: 15 | Loss: 16.6897
# Epoch 20 | Batch: 16 | Loss: 12.5868
# Epoch 20 | Batch: 17 | Loss: 20.0052
# Epoch 20 | Batch: 18 | Loss: 21.2127
# Epoch 20 | Batch: 19 | Loss: 11.7965
# Epoch 20 | Batch: 20 | Loss: 15.2630
# Epoch 20 | Batch: 21 | Loss: 16.0719
# Epoch 20 | Batch: 22 | Loss: 17.7253
# Epoch 20 | Batch: 23 | Loss: 17.0801
# Epoch 20 | Batch: 24 | Loss: 10.1538
# Epoch 21 | Batch: 1 | Loss: 19.6618
# Epoch 21 | Batch: 2 | Loss: 14.2206
# Epoch 21 | Batch: 3 | Loss: 12.7490
# Epoch 21 | Batch: 4 | Loss: 16.2991
# Epoch 21 | Batch: 5 | Loss: 16.3933
# Epoch 21 | Batch: 6 | Loss: 14.3702
# Epoch 21 | Batch: 7 | Loss: 11.2187
# Epoch 21 | Batch: 8 | Loss: 14.9071
# Epoch 21 | Batch: 9 | Loss: 25.9414
# Epoch 21 | Batch: 10 | Loss: 23.4487
# Epoch 21 | Batch: 11 | Loss: 15.5748
# Epoch 21 | Batch: 12 | Loss: 15.8914
# Epoch 21 | Batch: 13 | Loss: 15.3101
# Epoch 21 | Batch: 14 | Loss: 15.6008
# Epoch 21 | Batch: 15 | Loss: 17.2329
# Epoch 21 | Batch: 16 | Loss: 13.1179
# Epoch 21 | Batch: 17 | Loss: 12.2922
# Epoch 21 | Batch: 18 | Loss: 15.1770
# Epoch 21 | Batch: 19 | Loss: 15.7475
# Epoch 21 | Batch: 20 | Loss: 14.5862
# Epoch 21 | Batch: 21 | Loss: 13.4928
# Epoch 21 | Batch: 22 | Loss: 15.6643
# Epoch 21 | Batch: 23 | Loss: 20.9257
# Epoch 21 | Batch: 24 | Loss: 11.3921
# Epoch 22 | Batch: 1 | Loss: 12.8511
# Epoch 22 | Batch: 2 | Loss: 16.3298
# Epoch 22 | Batch: 3 | Loss: 15.1737
# Epoch 22 | Batch: 4 | Loss: 12.5295
# Epoch 22 | Batch: 5 | Loss: 16.1547
# Epoch 22 | Batch: 6 | Loss: 13.7044
# Epoch 22 | Batch: 7 | Loss: 16.5455
# Epoch 22 | Batch: 8 | Loss: 9.8139
# Epoch 22 | Batch: 9 | Loss: 20.3543
# Epoch 22 | Batch: 10 | Loss: 18.8612
# Epoch 22 | Batch: 11 | Loss: 15.4817
# Epoch 22 | Batch: 12 | Loss: 17.0844
# Epoch 22 | Batch: 13 | Loss: 14.6147
# Epoch 22 | Batch: 14 | Loss: 13.7990
# Epoch 22 | Batch: 15 | Loss: 14.9252
# Epoch 22 | Batch: 16 | Loss: 17.7445
# Epoch 22 | Batch: 17 | Loss: 18.7217
# Epoch 22 | Batch: 18 | Loss: 11.1292
# Epoch 22 | Batch: 19 | Loss: 15.7261
# Epoch 22 | Batch: 20 | Loss: 12.3654
# Epoch 22 | Batch: 21 | Loss: 23.0452
# Epoch 22 | Batch: 22 | Loss: 15.9180
# Epoch 22 | Batch: 23 | Loss: 17.9435
# Epoch 22 | Batch: 24 | Loss: 9.4230
# Epoch 23 | Batch: 1 | Loss: 14.9660
# Epoch 23 | Batch: 2 | Loss: 12.1658
# Epoch 23 | Batch: 3 | Loss: 10.1105
# Epoch 23 | Batch: 4 | Loss: 13.6121
# Epoch 23 | Batch: 5 | Loss: 18.2883
# Epoch 23 | Batch: 6 | Loss: 12.9244
# Epoch 23 | Batch: 7 | Loss: 14.1346
# Epoch 23 | Batch: 8 | Loss: 10.3176
# Epoch 23 | Batch: 9 | Loss: 27.9701
# Epoch 23 | Batch: 10 | Loss: 25.5770
# Epoch 23 | Batch: 11 | Loss: 16.6141
# Epoch 23 | Batch: 12 | Loss: 19.0951
# Epoch 23 | Batch: 13 | Loss: 12.3410
# Epoch 23 | Batch: 14 | Loss: 12.0695
# Epoch 23 | Batch: 15 | Loss: 13.5410
# Epoch 23 | Batch: 16 | Loss: 20.4483
# Epoch 23 | Batch: 17 | Loss: 21.0157
# Epoch 23 | Batch: 18 | Loss: 13.6521
# Epoch 23 | Batch: 19 | Loss: 10.0246
# Epoch 23 | Batch: 20 | Loss: 11.4502
# Epoch 23 | Batch: 21 | Loss: 20.9819
# Epoch 23 | Batch: 22 | Loss: 20.3876
# Epoch 23 | Batch: 23 | Loss: 20.5376
# Epoch 23 | Batch: 24 | Loss: 12.1957
# Epoch 24 | Batch: 1 | Loss: 14.1350
# Epoch 24 | Batch: 2 | Loss: 15.0262
# Epoch 24 | Batch: 3 | Loss: 17.8595
# Epoch 24 | Batch: 4 | Loss: 11.0532
# Epoch 24 | Batch: 5 | Loss: 16.0183
# Epoch 24 | Batch: 6 | Loss: 13.9542
# Epoch 24 | Batch: 7 | Loss: 16.1231
# Epoch 24 | Batch: 8 | Loss: 16.0720
# Epoch 24 | Batch: 9 | Loss: 16.2605
# Epoch 24 | Batch: 10 | Loss: 15.9390
# Epoch 24 | Batch: 11 | Loss: 20.0905
# Epoch 24 | Batch: 12 | Loss: 12.8044
# Epoch 24 | Batch: 13 | Loss: 20.3299
# Epoch 24 | Batch: 14 | Loss: 17.5895
# Epoch 24 | Batch: 15 | Loss: 15.8502
# Epoch 24 | Batch: 16 | Loss: 14.3622
# Epoch 24 | Batch: 17 | Loss: 12.9524
# Epoch 24 | Batch: 18 | Loss: 19.2444
# Epoch 24 | Batch: 19 | Loss: 11.9722
# Epoch 24 | Batch: 20 | Loss: 15.1708
# Epoch 24 | Batch: 21 | Loss: 14.9998
# Epoch 24 | Batch: 22 | Loss: 14.6066
# Epoch 24 | Batch: 23 | Loss: 15.4882
# Epoch 24 | Batch: 24 | Loss: 7.0898
# Epoch 25 | Batch: 1 | Loss: 13.2675
# Epoch 25 | Batch: 2 | Loss: 15.7833
# Epoch 25 | Batch: 3 | Loss: 26.8929
# Epoch 25 | Batch: 4 | Loss: 22.2652
# Epoch 25 | Batch: 5 | Loss: 23.1467
# Epoch 25 | Batch: 6 | Loss: 18.9900
# Epoch 25 | Batch: 7 | Loss: 12.9229
# Epoch 25 | Batch: 8 | Loss: 11.6085
# Epoch 25 | Batch: 9 | Loss: 19.2458
# Epoch 25 | Batch: 10 | Loss: 15.3495
# Epoch 25 | Batch: 11 | Loss: 18.8718
# Epoch 25 | Batch: 12 | Loss: 12.0195
# Epoch 25 | Batch: 13 | Loss: 13.2836
# Epoch 25 | Batch: 14 | Loss: 14.6979
# Epoch 25 | Batch: 15 | Loss: 18.5200
# Epoch 25 | Batch: 16 | Loss: 16.3074
# Epoch 25 | Batch: 17 | Loss: 12.0229
# Epoch 25 | Batch: 18 | Loss: 14.6954
# Epoch 25 | Batch: 19 | Loss: 17.3898
# Epoch 25 | Batch: 20 | Loss: 18.2323
# Epoch 25 | Batch: 21 | Loss: 17.0860
# Epoch 25 | Batch: 22 | Loss: 12.1177
# Epoch 25 | Batch: 23 | Loss: 15.9505
# Epoch 25 | Batch: 24 | Loss: 8.7848
# Epoch 26 | Batch: 1 | Loss: 15.2228
# Epoch 26 | Batch: 2 | Loss: 15.1768
# Epoch 26 | Batch: 3 | Loss: 16.0039
# Epoch 26 | Batch: 4 | Loss: 14.7158
# Epoch 26 | Batch: 5 | Loss: 21.7880
# Epoch 26 | Batch: 6 | Loss: 15.0672
# Epoch 26 | Batch: 7 | Loss: 17.2021
# Epoch 26 | Batch: 8 | Loss: 13.9727
# Epoch 26 | Batch: 9 | Loss: 20.7482
# Epoch 26 | Batch: 10 | Loss: 14.5772
# Epoch 26 | Batch: 11 | Loss: 13.8001
# Epoch 26 | Batch: 12 | Loss: 14.6608
# Epoch 26 | Batch: 13 | Loss: 9.4904
# Epoch 26 | Batch: 14 | Loss: 15.9483
# Epoch 26 | Batch: 15 | Loss: 17.1985
# Epoch 26 | Batch: 16 | Loss: 17.5772
# Epoch 26 | Batch: 17 | Loss: 18.0051
# Epoch 26 | Batch: 18 | Loss: 16.9515
# Epoch 26 | Batch: 19 | Loss: 14.6736
# Epoch 26 | Batch: 20 | Loss: 18.0285
# Epoch 26 | Batch: 21 | Loss: 17.1625
# Epoch 26 | Batch: 22 | Loss: 11.5473
# Epoch 26 | Batch: 23 | Loss: 10.4500
# Epoch 26 | Batch: 24 | Loss: 12.5602
# Epoch 27 | Batch: 1 | Loss: 18.0195
# Epoch 27 | Batch: 2 | Loss: 15.4017
# Epoch 27 | Batch: 3 | Loss: 15.1382
# Epoch 27 | Batch: 4 | Loss: 13.6807
# Epoch 27 | Batch: 5 | Loss: 12.8289
# Epoch 27 | Batch: 6 | Loss: 13.0250
# Epoch 27 | Batch: 7 | Loss: 12.6093
# Epoch 27 | Batch: 8 | Loss: 12.0404
# Epoch 27 | Batch: 9 | Loss: 16.6660
# Epoch 27 | Batch: 10 | Loss: 15.4323
# Epoch 27 | Batch: 11 | Loss: 13.6759
# Epoch 27 | Batch: 12 | Loss: 14.7641
# Epoch 27 | Batch: 13 | Loss: 16.6759
# Epoch 27 | Batch: 14 | Loss: 14.2631
# Epoch 27 | Batch: 15 | Loss: 17.9144
# Epoch 27 | Batch: 16 | Loss: 19.2072
# Epoch 27 | Batch: 17 | Loss: 12.8750
# Epoch 27 | Batch: 18 | Loss: 16.9082
# Epoch 27 | Batch: 19 | Loss: 15.3098
# Epoch 27 | Batch: 20 | Loss: 15.0626
# Epoch 27 | Batch: 21 | Loss: 19.0594
# Epoch 27 | Batch: 22 | Loss: 13.6365
# Epoch 27 | Batch: 23 | Loss: 16.2098
# Epoch 27 | Batch: 24 | Loss: 9.0700
# Epoch 28 | Batch: 1 | Loss: 14.9092
# Epoch 28 | Batch: 2 | Loss: 15.5080
# Epoch 28 | Batch: 3 | Loss: 15.3191
# Epoch 28 | Batch: 4 | Loss: 16.4355
# Epoch 28 | Batch: 5 | Loss: 22.8044
# Epoch 28 | Batch: 6 | Loss: 16.9409
# Epoch 28 | Batch: 7 | Loss: 17.0051
# Epoch 28 | Batch: 8 | Loss: 19.6968
# Epoch 28 | Batch: 9 | Loss: 12.9500
# Epoch 28 | Batch: 10 | Loss: 18.5001
# Epoch 28 | Batch: 11 | Loss: 15.2923
# Epoch 28 | Batch: 12 | Loss: 12.3750
# Epoch 28 | Batch: 13 | Loss: 19.4554
# Epoch 28 | Batch: 14 | Loss: 12.5254
# Epoch 28 | Batch: 15 | Loss: 21.7995
# Epoch 28 | Batch: 16 | Loss: 11.6450
# Epoch 28 | Batch: 17 | Loss: 14.3529
# Epoch 28 | Batch: 18 | Loss: 19.2942
# Epoch 28 | Batch: 19 | Loss: 12.7620
# Epoch 28 | Batch: 20 | Loss: 21.6767
# Epoch 28 | Batch: 21 | Loss: 15.8494
# Epoch 28 | Batch: 22 | Loss: 13.7636
# Epoch 28 | Batch: 23 | Loss: 13.7053
# Epoch 28 | Batch: 24 | Loss: 13.4392
# Epoch 29 | Batch: 1 | Loss: 16.9310
# Epoch 29 | Batch: 2 | Loss: 16.1825
# Epoch 29 | Batch: 3 | Loss: 13.1346
# Epoch 29 | Batch: 4 | Loss: 11.9026
# Epoch 29 | Batch: 5 | Loss: 13.7902
# Epoch 29 | Batch: 6 | Loss: 13.5521
# Epoch 29 | Batch: 7 | Loss: 13.7404
# Epoch 29 | Batch: 8 | Loss: 15.7863
# Epoch 29 | Batch: 9 | Loss: 11.1556
# Epoch 29 | Batch: 10 | Loss: 14.9990
# Epoch 29 | Batch: 11 | Loss: 20.6345
# Epoch 29 | Batch: 12 | Loss: 15.1261
# Epoch 29 | Batch: 13 | Loss: 14.9398
# Epoch 29 | Batch: 14 | Loss: 19.7953
# Epoch 29 | Batch: 15 | Loss: 15.0833
# Epoch 29 | Batch: 16 | Loss: 18.4142
# Epoch 29 | Batch: 17 | Loss: 13.9941
# Epoch 29 | Batch: 18 | Loss: 15.2490
# Epoch 29 | Batch: 19 | Loss: 16.4646
# Epoch 29 | Batch: 20 | Loss: 20.3381
# Epoch 29 | Batch: 21 | Loss: 16.2560
# Epoch 29 | Batch: 22 | Loss: 13.9949
# Epoch 29 | Batch: 23 | Loss: 13.1248
# Epoch 29 | Batch: 24 | Loss: 10.1690
# Epoch 30 | Batch: 1 | Loss: 11.3432
# Epoch 30 | Batch: 2 | Loss: 20.3903
# Epoch 30 | Batch: 3 | Loss: 16.3199
# Epoch 30 | Batch: 4 | Loss: 15.6384
# Epoch 30 | Batch: 5 | Loss: 17.7371
# Epoch 30 | Batch: 6 | Loss: 14.6160
# Epoch 30 | Batch: 7 | Loss: 10.9455
# Epoch 30 | Batch: 8 | Loss: 14.9380
# Epoch 30 | Batch: 9 | Loss: 13.9634
# Epoch 30 | Batch: 10 | Loss: 12.7054
# Epoch 30 | Batch: 11 | Loss: 16.1948
# Epoch 30 | Batch: 12 | Loss: 21.3536
# Epoch 30 | Batch: 13 | Loss: 17.1814
# Epoch 30 | Batch: 14 | Loss: 14.6237
# Epoch 30 | Batch: 15 | Loss: 18.2402
# Epoch 30 | Batch: 16 | Loss: 18.5019
# Epoch 30 | Batch: 17 | Loss: 15.5675
# Epoch 30 | Batch: 18 | Loss: 17.5852
# Epoch 30 | Batch: 19 | Loss: 15.0248
# Epoch 30 | Batch: 20 | Loss: 12.9374
# Epoch 30 | Batch: 21 | Loss: 13.6901
# Epoch 30 | Batch: 22 | Loss: 16.4058
# Epoch 30 | Batch: 23 | Loss: 11.3187
# Epoch 30 | Batch: 24 | Loss: 12.1114
# Epoch 31 | Batch: 1 | Loss: 20.4305
# Epoch 31 | Batch: 2 | Loss: 19.9250
# Epoch 31 | Batch: 3 | Loss: 11.1826
# Epoch 31 | Batch: 4 | Loss: 10.5025
# Epoch 31 | Batch: 5 | Loss: 10.6851
# Epoch 31 | Batch: 6 | Loss: 17.2741
# Epoch 31 | Batch: 7 | Loss: 19.2814
# Epoch 31 | Batch: 8 | Loss: 11.9921
# Epoch 31 | Batch: 9 | Loss: 16.1867
# Epoch 31 | Batch: 10 | Loss: 15.4819
# Epoch 31 | Batch: 11 | Loss: 14.0621
# Epoch 31 | Batch: 12 | Loss: 16.4605
# Epoch 31 | Batch: 13 | Loss: 12.6584
# Epoch 31 | Batch: 14 | Loss: 11.5507
# Epoch 31 | Batch: 15 | Loss: 17.4843
# Epoch 31 | Batch: 16 | Loss: 13.8048
# Epoch 31 | Batch: 17 | Loss: 12.5986
# Epoch 31 | Batch: 18 | Loss: 21.2735
# Epoch 31 | Batch: 19 | Loss: 18.3429
# Epoch 31 | Batch: 20 | Loss: 18.9516
# Epoch 31 | Batch: 21 | Loss: 16.2393
# Epoch 31 | Batch: 22 | Loss: 16.7061
# Epoch 31 | Batch: 23 | Loss: 15.5764
# Epoch 31 | Batch: 24 | Loss: 6.9375
# Epoch 32 | Batch: 1 | Loss: 13.0141
# Epoch 32 | Batch: 2 | Loss: 15.8574
# Epoch 32 | Batch: 3 | Loss: 12.4455
# Epoch 32 | Batch: 4 | Loss: 14.7189
# Epoch 32 | Batch: 5 | Loss: 19.9684
# Epoch 32 | Batch: 6 | Loss: 16.1531
# Epoch 32 | Batch: 7 | Loss: 11.4666
# Epoch 32 | Batch: 8 | Loss: 13.5858
# Epoch 32 | Batch: 9 | Loss: 16.0592
# Epoch 32 | Batch: 10 | Loss: 15.7299
# Epoch 32 | Batch: 11 | Loss: 14.8591
# Epoch 32 | Batch: 12 | Loss: 16.2141
# Epoch 32 | Batch: 13 | Loss: 13.9525
# Epoch 32 | Batch: 14 | Loss: 15.3981
# Epoch 32 | Batch: 15 | Loss: 18.4167
# Epoch 32 | Batch: 16 | Loss: 18.6645
# Epoch 32 | Batch: 17 | Loss: 20.1320
# Epoch 32 | Batch: 18 | Loss: 18.0185
# Epoch 32 | Batch: 19 | Loss: 15.7775
# Epoch 32 | Batch: 20 | Loss: 14.2651
# Epoch 32 | Batch: 21 | Loss: 9.5041
# Epoch 32 | Batch: 22 | Loss: 21.7161
# Epoch 32 | Batch: 23 | Loss: 16.2353
# Epoch 32 | Batch: 24 | Loss: 14.1730
# Epoch 33 | Batch: 1 | Loss: 19.3143
# Epoch 33 | Batch: 2 | Loss: 16.5146
# Epoch 33 | Batch: 3 | Loss: 12.2016
# Epoch 33 | Batch: 4 | Loss: 12.7155
# Epoch 33 | Batch: 5 | Loss: 17.6534
# Epoch 33 | Batch: 6 | Loss: 16.4738
# Epoch 33 | Batch: 7 | Loss: 14.1450
# Epoch 33 | Batch: 8 | Loss: 16.3412
# Epoch 33 | Batch: 9 | Loss: 14.6380
# Epoch 33 | Batch: 10 | Loss: 18.2792
# Epoch 33 | Batch: 11 | Loss: 18.2832
# Epoch 33 | Batch: 12 | Loss: 14.0248
# Epoch 33 | Batch: 13 | Loss: 15.1553
# Epoch 33 | Batch: 14 | Loss: 15.3401
# Epoch 33 | Batch: 15 | Loss: 19.0596
# Epoch 33 | Batch: 16 | Loss: 13.5885
# Epoch 33 | Batch: 17 | Loss: 12.1806
# Epoch 33 | Batch: 18 | Loss: 15.2080
# Epoch 33 | Batch: 19 | Loss: 16.7691
# Epoch 33 | Batch: 20 | Loss: 12.8769
# Epoch 33 | Batch: 21 | Loss: 14.0020
# Epoch 33 | Batch: 22 | Loss: 17.2285
# Epoch 33 | Batch: 23 | Loss: 17.7836
# Epoch 33 | Batch: 24 | Loss: 11.4589
# Epoch 34 | Batch: 1 | Loss: 17.5352
# Epoch 34 | Batch: 2 | Loss: 18.9788
# Epoch 34 | Batch: 3 | Loss: 16.3316
# Epoch 34 | Batch: 4 | Loss: 14.3475
# Epoch 34 | Batch: 5 | Loss: 19.8979
# Epoch 34 | Batch: 6 | Loss: 13.8996
# Epoch 34 | Batch: 7 | Loss: 15.2364
# Epoch 34 | Batch: 8 | Loss: 15.1270
# Epoch 34 | Batch: 9 | Loss: 13.3271
# Epoch 34 | Batch: 10 | Loss: 11.0236
# Epoch 34 | Batch: 11 | Loss: 21.6145
# Epoch 34 | Batch: 12 | Loss: 21.7621
# Epoch 34 | Batch: 13 | Loss: 11.0067
# Epoch 34 | Batch: 14 | Loss: 17.9171
# Epoch 34 | Batch: 15 | Loss: 15.7124
# Epoch 34 | Batch: 16 | Loss: 12.5598
# Epoch 34 | Batch: 17 | Loss: 14.5226
# Epoch 34 | Batch: 18 | Loss: 16.7153
# Epoch 34 | Batch: 19 | Loss: 13.5282
# Epoch 34 | Batch: 20 | Loss: 15.0723
# Epoch 34 | Batch: 21 | Loss: 18.6873
# Epoch 34 | Batch: 22 | Loss: 17.2672
# Epoch 34 | Batch: 23 | Loss: 14.8891
# Epoch 34 | Batch: 24 | Loss: 11.0371
# Epoch 35 | Batch: 1 | Loss: 21.2896
# Epoch 35 | Batch: 2 | Loss: 12.6674
# Epoch 35 | Batch: 3 | Loss: 16.8005
# Epoch 35 | Batch: 4 | Loss: 15.3656
# Epoch 35 | Batch: 5 | Loss: 16.9274
# Epoch 35 | Batch: 6 | Loss: 19.2807
# Epoch 35 | Batch: 7 | Loss: 13.0438
# Epoch 35 | Batch: 8 | Loss: 14.8383
# Epoch 35 | Batch: 9 | Loss: 20.7407
# Epoch 35 | Batch: 10 | Loss: 18.9371
# Epoch 35 | Batch: 11 | Loss: 16.8359
# Epoch 35 | Batch: 12 | Loss: 13.8061
# Epoch 35 | Batch: 13 | Loss: 16.1823
# Epoch 35 | Batch: 14 | Loss: 13.7136
# Epoch 35 | Batch: 15 | Loss: 13.3171
# Epoch 35 | Batch: 16 | Loss: 13.2571
# Epoch 35 | Batch: 17 | Loss: 13.2764
# Epoch 35 | Batch: 18 | Loss: 17.8899
# Epoch 35 | Batch: 19 | Loss: 14.0592
# Epoch 35 | Batch: 20 | Loss: 13.9124
# Epoch 35 | Batch: 21 | Loss: 14.1063
# Epoch 35 | Batch: 22 | Loss: 15.4234
# Epoch 35 | Batch: 23 | Loss: 13.8752
# Epoch 35 | Batch: 24 | Loss: 8.5157
# Epoch 36 | Batch: 1 | Loss: 20.2727
# Epoch 36 | Batch: 2 | Loss: 14.3907
# Epoch 36 | Batch: 3 | Loss: 13.4000
# Epoch 36 | Batch: 4 | Loss: 17.2202
# Epoch 36 | Batch: 5 | Loss: 14.5829
# Epoch 36 | Batch: 6 | Loss: 13.8540
# Epoch 36 | Batch: 7 | Loss: 14.5962
# Epoch 36 | Batch: 8 | Loss: 14.8794
# Epoch 36 | Batch: 9 | Loss: 15.0678
# Epoch 36 | Batch: 10 | Loss: 18.2007
# Epoch 36 | Batch: 11 | Loss: 13.7950
# Epoch 36 | Batch: 12 | Loss: 18.9081
# Epoch 36 | Batch: 13 | Loss: 14.8662
# Epoch 36 | Batch: 14 | Loss: 17.7423
# Epoch 36 | Batch: 15 | Loss: 12.7525
# Epoch 36 | Batch: 16 | Loss: 12.2584
# Epoch 36 | Batch: 17 | Loss: 12.1540
# Epoch 36 | Batch: 18 | Loss: 17.4316
# Epoch 36 | Batch: 19 | Loss: 18.3946
# Epoch 36 | Batch: 20 | Loss: 17.0359
# Epoch 36 | Batch: 21 | Loss: 14.7453
# Epoch 36 | Batch: 22 | Loss: 14.0291
# Epoch 36 | Batch: 23 | Loss: 14.1876
# Epoch 36 | Batch: 24 | Loss: 15.0992
# Epoch 37 | Batch: 1 | Loss: 19.9049
# Epoch 37 | Batch: 2 | Loss: 15.4259
# Epoch 37 | Batch: 3 | Loss: 16.4763
# Epoch 37 | Batch: 4 | Loss: 12.9222
# Epoch 37 | Batch: 5 | Loss: 11.6641
# Epoch 37 | Batch: 6 | Loss: 14.6351
# Epoch 37 | Batch: 7 | Loss: 17.3645
# Epoch 37 | Batch: 8 | Loss: 22.7973
# Epoch 37 | Batch: 9 | Loss: 15.0680
# Epoch 37 | Batch: 10 | Loss: 21.6829
# Epoch 37 | Batch: 11 | Loss: 14.4572
# Epoch 37 | Batch: 12 | Loss: 11.7287
# Epoch 37 | Batch: 13 | Loss: 14.7558
# Epoch 37 | Batch: 14 | Loss: 18.2974
# Epoch 37 | Batch: 15 | Loss: 17.5791
# Epoch 37 | Batch: 16 | Loss: 12.0301
# Epoch 37 | Batch: 17 | Loss: 14.3744
# Epoch 37 | Batch: 18 | Loss: 10.1108
# Epoch 37 | Batch: 19 | Loss: 18.2682
# Epoch 37 | Batch: 20 | Loss: 12.9753
# Epoch 37 | Batch: 21 | Loss: 14.7619
# Epoch 37 | Batch: 22 | Loss: 19.8947
# Epoch 37 | Batch: 23 | Loss: 19.7041
# Epoch 37 | Batch: 24 | Loss: 11.1556
# Epoch 38 | Batch: 1 | Loss: 16.8789
# Epoch 38 | Batch: 2 | Loss: 19.3587
# Epoch 38 | Batch: 3 | Loss: 14.7280
# Epoch 38 | Batch: 4 | Loss: 11.9804
# Epoch 38 | Batch: 5 | Loss: 17.1226
# Epoch 38 | Batch: 6 | Loss: 19.6841
# Epoch 38 | Batch: 7 | Loss: 11.4518
# Epoch 38 | Batch: 8 | Loss: 14.3815
# Epoch 38 | Batch: 9 | Loss: 14.9743
# Epoch 38 | Batch: 10 | Loss: 19.8840
# Epoch 38 | Batch: 11 | Loss: 14.8506
# Epoch 38 | Batch: 12 | Loss: 16.4415
# Epoch 38 | Batch: 13 | Loss: 16.6584
# Epoch 38 | Batch: 14 | Loss: 15.6344
# Epoch 38 | Batch: 15 | Loss: 13.8339
# Epoch 38 | Batch: 16 | Loss: 15.1091
# Epoch 38 | Batch: 17 | Loss: 14.8602
# Epoch 38 | Batch: 18 | Loss: 14.4383
# Epoch 38 | Batch: 19 | Loss: 13.5480
# Epoch 38 | Batch: 20 | Loss: 19.9741
# Epoch 38 | Batch: 21 | Loss: 16.1313
# Epoch 38 | Batch: 22 | Loss: 16.1623
# Epoch 38 | Batch: 23 | Loss: 18.3962
# Epoch 38 | Batch: 24 | Loss: 13.9621
# Epoch 39 | Batch: 1 | Loss: 12.1136
# Epoch 39 | Batch: 2 | Loss: 14.2486
# Epoch 39 | Batch: 3 | Loss: 17.0537
# Epoch 39 | Batch: 4 | Loss: 13.3650
# Epoch 39 | Batch: 5 | Loss: 15.0239
# Epoch 39 | Batch: 6 | Loss: 16.3176
# Epoch 39 | Batch: 7 | Loss: 16.6329
# Epoch 39 | Batch: 8 | Loss: 12.9972
# Epoch 39 | Batch: 9 | Loss: 10.6266
# Epoch 39 | Batch: 10 | Loss: 19.5208
# Epoch 39 | Batch: 11 | Loss: 16.3382
# Epoch 39 | Batch: 12 | Loss: 19.0872
# Epoch 39 | Batch: 13 | Loss: 20.8757
# Epoch 39 | Batch: 14 | Loss: 16.1717
# Epoch 39 | Batch: 15 | Loss: 15.3220
# Epoch 39 | Batch: 16 | Loss: 15.7396
# Epoch 39 | Batch: 17 | Loss: 10.7379
# Epoch 39 | Batch: 18 | Loss: 13.1890
# Epoch 39 | Batch: 19 | Loss: 18.6832
# Epoch 39 | Batch: 20 | Loss: 20.7633
# Epoch 39 | Batch: 21 | Loss: 23.1752
# Epoch 39 | Batch: 22 | Loss: 15.3146
# Epoch 39 | Batch: 23 | Loss: 12.0049
# Epoch 39 | Batch: 24 | Loss: 13.7427
# Epoch 40 | Batch: 1 | Loss: 22.1453
# Epoch 40 | Batch: 2 | Loss: 15.9825
# Epoch 40 | Batch: 3 | Loss: 15.1089
# Epoch 40 | Batch: 4 | Loss: 14.8881
# Epoch 40 | Batch: 5 | Loss: 14.8218
# Epoch 40 | Batch: 6 | Loss: 10.7614
# Epoch 40 | Batch: 7 | Loss: 16.0738
# Epoch 40 | Batch: 8 | Loss: 9.0968
# Epoch 40 | Batch: 9 | Loss: 16.7547
# Epoch 40 | Batch: 10 | Loss: 18.9082
# Epoch 40 | Batch: 11 | Loss: 14.3676
# Epoch 40 | Batch: 12 | Loss: 9.4525
# Epoch 40 | Batch: 13 | Loss: 21.2545
# Epoch 40 | Batch: 14 | Loss: 12.8880
# Epoch 40 | Batch: 15 | Loss: 15.6606
# Epoch 40 | Batch: 16 | Loss: 14.4459
# Epoch 40 | Batch: 17 | Loss: 20.1271
# Epoch 40 | Batch: 18 | Loss: 15.1865
# Epoch 40 | Batch: 19 | Loss: 11.3886
# Epoch 40 | Batch: 20 | Loss: 14.1288
# Epoch 40 | Batch: 21 | Loss: 16.8049
# Epoch 40 | Batch: 22 | Loss: 21.6081
# Epoch 40 | Batch: 23 | Loss: 15.4778
# Epoch 40 | Batch: 24 | Loss: 11.7882
# Epoch 41 | Batch: 1 | Loss: 15.0099
# Epoch 41 | Batch: 2 | Loss: 8.2506
# Epoch 41 | Batch: 3 | Loss: 17.0440
# Epoch 41 | Batch: 4 | Loss: 14.1080
# Epoch 41 | Batch: 5 | Loss: 14.8427
# Epoch 41 | Batch: 6 | Loss: 16.5562
# Epoch 41 | Batch: 7 | Loss: 14.6702
# Epoch 41 | Batch: 8 | Loss: 17.1192
# Epoch 41 | Batch: 9 | Loss: 16.7660
# Epoch 41 | Batch: 10 | Loss: 16.0083
# Epoch 41 | Batch: 11 | Loss: 14.3309
# Epoch 41 | Batch: 12 | Loss: 17.6424
# Epoch 41 | Batch: 13 | Loss: 18.9041
# Epoch 41 | Batch: 14 | Loss: 17.1558
# Epoch 41 | Batch: 15 | Loss: 11.6890
# Epoch 41 | Batch: 16 | Loss: 15.7454
# Epoch 41 | Batch: 17 | Loss: 17.1707
# Epoch 41 | Batch: 18 | Loss: 16.3284
# Epoch 41 | Batch: 19 | Loss: 17.4501
# Epoch 41 | Batch: 20 | Loss: 17.2769
# Epoch 41 | Batch: 21 | Loss: 16.6698
# Epoch 41 | Batch: 22 | Loss: 19.0278
# Epoch 41 | Batch: 23 | Loss: 15.6666
# Epoch 41 | Batch: 24 | Loss: 10.6476
# Epoch 42 | Batch: 1 | Loss: 14.9575
# Epoch 42 | Batch: 2 | Loss: 14.4948
# Epoch 42 | Batch: 3 | Loss: 11.2076
# Epoch 42 | Batch: 4 | Loss: 19.2393
# Epoch 42 | Batch: 5 | Loss: 19.8160
# Epoch 42 | Batch: 6 | Loss: 10.2198
# Epoch 42 | Batch: 7 | Loss: 13.0094
# Epoch 42 | Batch: 8 | Loss: 26.0112
# Epoch 42 | Batch: 9 | Loss: 20.1699
# Epoch 42 | Batch: 10 | Loss: 11.3812
# Epoch 42 | Batch: 11 | Loss: 12.9288
# Epoch 42 | Batch: 12 | Loss: 21.4136
# Epoch 42 | Batch: 13 | Loss: 18.6515
# Epoch 42 | Batch: 14 | Loss: 12.0635
# Epoch 42 | Batch: 15 | Loss: 15.9158
# Epoch 42 | Batch: 16 | Loss: 13.2493
# Epoch 42 | Batch: 17 | Loss: 13.4389
# Epoch 42 | Batch: 18 | Loss: 16.9572
# Epoch 42 | Batch: 19 | Loss: 12.3608
# Epoch 42 | Batch: 20 | Loss: 19.5170
# Epoch 42 | Batch: 21 | Loss: 15.3731
# Epoch 42 | Batch: 22 | Loss: 15.6756
# Epoch 42 | Batch: 23 | Loss: 17.9959
# Epoch 42 | Batch: 24 | Loss: 10.5821
# Epoch 43 | Batch: 1 | Loss: 12.0170
# Epoch 43 | Batch: 2 | Loss: 16.7642
# Epoch 43 | Batch: 3 | Loss: 14.6806
# Epoch 43 | Batch: 4 | Loss: 12.0151
# Epoch 43 | Batch: 5 | Loss: 20.2189
# Epoch 43 | Batch: 6 | Loss: 19.0407
# Epoch 43 | Batch: 7 | Loss: 16.0608
# Epoch 43 | Batch: 8 | Loss: 16.4681
# Epoch 43 | Batch: 9 | Loss: 14.5598
# Epoch 43 | Batch: 10 | Loss: 16.1256
# Epoch 43 | Batch: 11 | Loss: 15.6374
# Epoch 43 | Batch: 12 | Loss: 16.9466
# Epoch 43 | Batch: 13 | Loss: 21.6702
# Epoch 43 | Batch: 14 | Loss: 14.6409
# Epoch 43 | Batch: 15 | Loss: 12.5673
# Epoch 43 | Batch: 16 | Loss: 13.3807
# Epoch 43 | Batch: 17 | Loss: 8.3406
# Epoch 43 | Batch: 18 | Loss: 13.9537
# Epoch 43 | Batch: 19 | Loss: 20.6346
# Epoch 43 | Batch: 20 | Loss: 17.1018
# Epoch 43 | Batch: 21 | Loss: 19.7034
# Epoch 43 | Batch: 22 | Loss: 19.8291
# Epoch 43 | Batch: 23 | Loss: 19.2629
# Epoch 43 | Batch: 24 | Loss: 9.2808
# Epoch 44 | Batch: 1 | Loss: 13.9289
# Epoch 44 | Batch: 2 | Loss: 15.0611
# Epoch 44 | Batch: 3 | Loss: 13.4528
# Epoch 44 | Batch: 4 | Loss: 10.0975
# Epoch 44 | Batch: 5 | Loss: 15.7253
# Epoch 44 | Batch: 6 | Loss: 20.3662
# Epoch 44 | Batch: 7 | Loss: 19.5177
# Epoch 44 | Batch: 8 | Loss: 20.5511
# Epoch 44 | Batch: 9 | Loss: 16.2983
# Epoch 44 | Batch: 10 | Loss: 14.6782
# Epoch 44 | Batch: 11 | Loss: 12.8119
# Epoch 44 | Batch: 12 | Loss: 18.3881
# Epoch 44 | Batch: 13 | Loss: 22.8175
# Epoch 44 | Batch: 14 | Loss: 16.1341
# Epoch 44 | Batch: 15 | Loss: 14.3298
# Epoch 44 | Batch: 16 | Loss: 16.3672
# Epoch 44 | Batch: 17 | Loss: 15.6891
# Epoch 44 | Batch: 18 | Loss: 16.9816
# Epoch 44 | Batch: 19 | Loss: 11.8789
# Epoch 44 | Batch: 20 | Loss: 17.6887
# Epoch 44 | Batch: 21 | Loss: 13.9362
# Epoch 44 | Batch: 22 | Loss: 12.6340
# Epoch 44 | Batch: 23 | Loss: 10.4320
# Epoch 44 | Batch: 24 | Loss: 13.6817
# Epoch 45 | Batch: 1 | Loss: 16.9501
# Epoch 45 | Batch: 2 | Loss: 14.2315
# Epoch 45 | Batch: 3 | Loss: 13.5464
# Epoch 45 | Batch: 4 | Loss: 19.1335
# Epoch 45 | Batch: 5 | Loss: 12.8754
# Epoch 45 | Batch: 6 | Loss: 9.7403
# Epoch 45 | Batch: 7 | Loss: 13.7960
# Epoch 45 | Batch: 8 | Loss: 20.1573
# Epoch 45 | Batch: 9 | Loss: 14.6019
# Epoch 45 | Batch: 10 | Loss: 17.6314
# Epoch 45 | Batch: 11 | Loss: 15.0106
# Epoch 45 | Batch: 12 | Loss: 16.0820
# Epoch 45 | Batch: 13 | Loss: 14.7539
# Epoch 45 | Batch: 14 | Loss: 17.8606
# Epoch 45 | Batch: 15 | Loss: 15.6513
# Epoch 45 | Batch: 16 | Loss: 16.8799
# Epoch 45 | Batch: 17 | Loss: 15.7996
# Epoch 45 | Batch: 18 | Loss: 17.4712
# Epoch 45 | Batch: 19 | Loss: 11.6591
# Epoch 45 | Batch: 20 | Loss: 16.4416
# Epoch 45 | Batch: 21 | Loss: 10.6058
# Epoch 45 | Batch: 22 | Loss: 14.7892
# Epoch 45 | Batch: 23 | Loss: 15.1005
# Epoch 45 | Batch: 24 | Loss: 7.9677
# Epoch 46 | Batch: 1 | Loss: 23.5229
# Epoch 46 | Batch: 2 | Loss: 14.9674
# Epoch 46 | Batch: 3 | Loss: 19.6424
# Epoch 46 | Batch: 4 | Loss: 16.5376
# Epoch 46 | Batch: 5 | Loss: 12.6222
# Epoch 46 | Batch: 6 | Loss: 11.7616
# Epoch 46 | Batch: 7 | Loss: 11.2918
# Epoch 46 | Batch: 8 | Loss: 17.0330
# Epoch 46 | Batch: 9 | Loss: 13.0947
# Epoch 46 | Batch: 10 | Loss: 19.8112
# Epoch 46 | Batch: 11 | Loss: 9.8933
# Epoch 46 | Batch: 12 | Loss: 16.3570
# Epoch 46 | Batch: 13 | Loss: 12.8900
# Epoch 46 | Batch: 14 | Loss: 12.8292
# Epoch 46 | Batch: 15 | Loss: 18.2169
# Epoch 46 | Batch: 16 | Loss: 18.7659
# Epoch 46 | Batch: 17 | Loss: 17.1337
# Epoch 46 | Batch: 18 | Loss: 12.6562
# Epoch 46 | Batch: 19 | Loss: 15.6449
# Epoch 46 | Batch: 20 | Loss: 13.2679
# Epoch 46 | Batch: 21 | Loss: 15.1588
# Epoch 46 | Batch: 22 | Loss: 16.8431
# Epoch 46 | Batch: 23 | Loss: 17.1950
# Epoch 46 | Batch: 24 | Loss: 11.2878
# Epoch 47 | Batch: 1 | Loss: 18.1932
# Epoch 47 | Batch: 2 | Loss: 13.3054
# Epoch 47 | Batch: 3 | Loss: 17.3179
# Epoch 47 | Batch: 4 | Loss: 14.5570
# Epoch 47 | Batch: 5 | Loss: 11.2861
# Epoch 47 | Batch: 6 | Loss: 14.0363
# Epoch 47 | Batch: 7 | Loss: 20.2271
# Epoch 47 | Batch: 8 | Loss: 19.6251
# Epoch 47 | Batch: 9 | Loss: 13.4416
# Epoch 47 | Batch: 10 | Loss: 14.5641
# Epoch 47 | Batch: 11 | Loss: 16.5711
# Epoch 47 | Batch: 12 | Loss: 17.8900
# Epoch 47 | Batch: 13 | Loss: 17.5428
# Epoch 47 | Batch: 14 | Loss: 15.6486
# Epoch 47 | Batch: 15 | Loss: 10.5407
# Epoch 47 | Batch: 16 | Loss: 13.1077
# Epoch 47 | Batch: 17 | Loss: 16.4508
# Epoch 47 | Batch: 18 | Loss: 16.0622
# Epoch 47 | Batch: 19 | Loss: 9.5976
# Epoch 47 | Batch: 20 | Loss: 19.6647
# Epoch 47 | Batch: 21 | Loss: 12.9151
# Epoch 47 | Batch: 22 | Loss: 14.5693
# Epoch 47 | Batch: 23 | Loss: 20.6828
# Epoch 47 | Batch: 24 | Loss: 11.7321
# Epoch 48 | Batch: 1 | Loss: 15.5382
# Epoch 48 | Batch: 2 | Loss: 9.1878
# Epoch 48 | Batch: 3 | Loss: 12.1001
# Epoch 48 | Batch: 4 | Loss: 12.3680
# Epoch 48 | Batch: 5 | Loss: 14.0219
# Epoch 48 | Batch: 6 | Loss: 18.3543
# Epoch 48 | Batch: 7 | Loss: 15.7117
# Epoch 48 | Batch: 8 | Loss: 15.2316
# Epoch 48 | Batch: 9 | Loss: 8.1767
# Epoch 48 | Batch: 10 | Loss: 12.5817
# Epoch 48 | Batch: 11 | Loss: 11.6850
# Epoch 48 | Batch: 12 | Loss: 23.8138
# Epoch 48 | Batch: 13 | Loss: 29.0899
# Epoch 48 | Batch: 14 | Loss: 18.9946
# Epoch 48 | Batch: 15 | Loss: 22.1583
# Epoch 48 | Batch: 16 | Loss: 11.5948
# Epoch 48 | Batch: 17 | Loss: 11.9972
# Epoch 48 | Batch: 18 | Loss: 12.4397
# Epoch 48 | Batch: 19 | Loss: 17.9428
# Epoch 48 | Batch: 20 | Loss: 16.9643
# Epoch 48 | Batch: 21 | Loss: 13.9609
# Epoch 48 | Batch: 22 | Loss: 21.9343
# Epoch 48 | Batch: 23 | Loss: 17.3301
# Epoch 48 | Batch: 24 | Loss: 14.2750
# Epoch 49 | Batch: 1 | Loss: 17.8153
# Epoch 49 | Batch: 2 | Loss: 16.2721
# Epoch 49 | Batch: 3 | Loss: 14.6372
# Epoch 49 | Batch: 4 | Loss: 8.7319
# Epoch 49 | Batch: 5 | Loss: 19.5687
# Epoch 49 | Batch: 6 | Loss: 18.8715
# Epoch 49 | Batch: 7 | Loss: 17.9923
# Epoch 49 | Batch: 8 | Loss: 13.1968
# Epoch 49 | Batch: 9 | Loss: 18.0046
# Epoch 49 | Batch: 10 | Loss: 13.8021
# Epoch 49 | Batch: 11 | Loss: 10.8025
# Epoch 49 | Batch: 12 | Loss: 18.5631
# Epoch 49 | Batch: 13 | Loss: 12.0896
# Epoch 49 | Batch: 14 | Loss: 12.5295
# Epoch 49 | Batch: 15 | Loss: 11.1804
# Epoch 49 | Batch: 16 | Loss: 12.6666
# Epoch 49 | Batch: 17 | Loss: 13.5136
# Epoch 49 | Batch: 18 | Loss: 17.5630
# Epoch 49 | Batch: 19 | Loss: 20.5991
# Epoch 49 | Batch: 20 | Loss: 17.9151
# Epoch 49 | Batch: 21 | Loss: 18.2261
# Epoch 49 | Batch: 22 | Loss: 16.0039
# Epoch 49 | Batch: 23 | Loss: 17.1038
# Epoch 49 | Batch: 24 | Loss: 9.0641
# Epoch 50 | Batch: 1 | Loss: 17.2606
# Epoch 50 | Batch: 2 | Loss: 15.5985
# Epoch 50 | Batch: 3 | Loss: 14.7993
# Epoch 50 | Batch: 4 | Loss: 10.8139
# Epoch 50 | Batch: 5 | Loss: 10.7523
# Epoch 50 | Batch: 6 | Loss: 14.5761
# Epoch 50 | Batch: 7 | Loss: 12.9734
# Epoch 50 | Batch: 8 | Loss: 9.8249
# Epoch 50 | Batch: 9 | Loss: 10.7364
# Epoch 50 | Batch: 10 | Loss: 19.8301
# Epoch 50 | Batch: 11 | Loss: 13.9938
# Epoch 50 | Batch: 12 | Loss: 20.0940
# Epoch 50 | Batch: 13 | Loss: 14.0384
# Epoch 50 | Batch: 14 | Loss: 17.6959
# Epoch 50 | Batch: 15 | Loss: 16.6638
# Epoch 50 | Batch: 16 | Loss: 12.7190
# Epoch 50 | Batch: 17 | Loss: 16.1041
# Epoch 50 | Batch: 18 | Loss: 19.3229
# Epoch 50 | Batch: 19 | Loss: 16.0493
# Epoch 50 | Batch: 20 | Loss: 22.9957
# Epoch 50 | Batch: 21 | Loss: 15.1307
# Epoch 50 | Batch: 22 | Loss: 15.0317
# Epoch 50 | Batch: 23 | Loss: 22.8963
# Epoch 50 | Batch: 24 | Loss: 12.0289
# Epoch 51 | Batch: 1 | Loss: 12.5716
# Epoch 51 | Batch: 2 | Loss: 16.2814
# Epoch 51 | Batch: 3 | Loss: 14.6674
# Epoch 51 | Batch: 4 | Loss: 13.0276
# Epoch 51 | Batch: 5 | Loss: 16.6490
# Epoch 51 | Batch: 6 | Loss: 17.2115
# Epoch 51 | Batch: 7 | Loss: 19.7510
# Epoch 51 | Batch: 8 | Loss: 14.6217
# Epoch 51 | Batch: 9 | Loss: 17.9187
# Epoch 51 | Batch: 10 | Loss: 10.9077
# Epoch 51 | Batch: 11 | Loss: 12.3460
# Epoch 51 | Batch: 12 | Loss: 16.4293
# Epoch 51 | Batch: 13 | Loss: 14.1759
# Epoch 51 | Batch: 14 | Loss: 21.1576
# Epoch 51 | Batch: 15 | Loss: 16.1770
# Epoch 51 | Batch: 16 | Loss: 16.7216
# Epoch 51 | Batch: 17 | Loss: 14.8515
# Epoch 51 | Batch: 18 | Loss: 15.0582
# Epoch 51 | Batch: 19 | Loss: 13.8328
# Epoch 51 | Batch: 20 | Loss: 16.1057
# Epoch 51 | Batch: 21 | Loss: 13.4206
# Epoch 51 | Batch: 22 | Loss: 10.6598
# Epoch 51 | Batch: 23 | Loss: 17.4434
# Epoch 51 | Batch: 24 | Loss: 9.0529
# Epoch 52 | Batch: 1 | Loss: 14.4141
# Epoch 52 | Batch: 2 | Loss: 12.0390
# Epoch 52 | Batch: 3 | Loss: 14.0519
# Epoch 52 | Batch: 4 | Loss: 14.5808
# Epoch 52 | Batch: 5 | Loss: 15.7955
# Epoch 52 | Batch: 6 | Loss: 15.1069
# Epoch 52 | Batch: 7 | Loss: 16.8178
# Epoch 52 | Batch: 8 | Loss: 15.2690
# Epoch 52 | Batch: 9 | Loss: 10.6775
# Epoch 52 | Batch: 10 | Loss: 15.6070
# Epoch 52 | Batch: 11 | Loss: 18.1929
# Epoch 52 | Batch: 12 | Loss: 17.2693
# Epoch 52 | Batch: 13 | Loss: 18.8827
# Epoch 52 | Batch: 14 | Loss: 11.2201
# Epoch 52 | Batch: 15 | Loss: 13.8124
# Epoch 52 | Batch: 16 | Loss: 21.8993
# Epoch 52 | Batch: 17 | Loss: 13.5083
# Epoch 52 | Batch: 18 | Loss: 13.4687
# Epoch 52 | Batch: 19 | Loss: 14.8280
# Epoch 52 | Batch: 20 | Loss: 18.9357
# Epoch 52 | Batch: 21 | Loss: 13.1897
# Epoch 52 | Batch: 22 | Loss: 11.3025
# Epoch 52 | Batch: 23 | Loss: 16.5028
# Epoch 52 | Batch: 24 | Loss: 8.5831
# Epoch 53 | Batch: 1 | Loss: 19.6980
# Epoch 53 | Batch: 2 | Loss: 16.5171
# Epoch 53 | Batch: 3 | Loss: 13.6353
# Epoch 53 | Batch: 4 | Loss: 17.8888
# Epoch 53 | Batch: 5 | Loss: 9.0023
# Epoch 53 | Batch: 6 | Loss: 14.6956
# Epoch 53 | Batch: 7 | Loss: 13.7813
# Epoch 53 | Batch: 8 | Loss: 16.3994
# Epoch 53 | Batch: 9 | Loss: 14.4759
# Epoch 53 | Batch: 10 | Loss: 13.3403
# Epoch 53 | Batch: 11 | Loss: 19.0007
# Epoch 53 | Batch: 12 | Loss: 14.1172
# Epoch 53 | Batch: 13 | Loss: 14.6208
# Epoch 53 | Batch: 14 | Loss: 15.8312
# Epoch 53 | Batch: 15 | Loss: 16.1192
# Epoch 53 | Batch: 16 | Loss: 18.7032
# Epoch 53 | Batch: 17 | Loss: 13.3262
# Epoch 53 | Batch: 18 | Loss: 13.8568
# Epoch 53 | Batch: 19 | Loss: 19.2640
# Epoch 53 | Batch: 20 | Loss: 13.5090
# Epoch 53 | Batch: 21 | Loss: 13.4198
# Epoch 53 | Batch: 22 | Loss: 12.0177
# Epoch 53 | Batch: 23 | Loss: 14.9032
# Epoch 53 | Batch: 24 | Loss: 11.6107
# Epoch 54 | Batch: 1 | Loss: 17.1999
# Epoch 54 | Batch: 2 | Loss: 15.8930
# Epoch 54 | Batch: 3 | Loss: 15.1018
# Epoch 54 | Batch: 4 | Loss: 11.1507
# Epoch 54 | Batch: 5 | Loss: 15.3959
# Epoch 54 | Batch: 6 | Loss: 17.3928
# Epoch 54 | Batch: 7 | Loss: 14.6460
# Epoch 54 | Batch: 8 | Loss: 11.3651
# Epoch 54 | Batch: 9 | Loss: 8.7411
# Epoch 54 | Batch: 10 | Loss: 16.4496
# Epoch 54 | Batch: 11 | Loss: 16.3303
# Epoch 54 | Batch: 12 | Loss: 23.0222
# Epoch 54 | Batch: 13 | Loss: 18.1943
# Epoch 54 | Batch: 14 | Loss: 11.1479
# Epoch 54 | Batch: 15 | Loss: 14.0510
# Epoch 54 | Batch: 16 | Loss: 14.5975
# Epoch 54 | Batch: 17 | Loss: 10.6045
# Epoch 54 | Batch: 18 | Loss: 9.7020
# Epoch 54 | Batch: 19 | Loss: 19.3226
# Epoch 54 | Batch: 20 | Loss: 15.7747
# Epoch 54 | Batch: 21 | Loss: 13.1502
# Epoch 54 | Batch: 22 | Loss: 17.4628
# Epoch 54 | Batch: 23 | Loss: 18.7858
# Epoch 54 | Batch: 24 | Loss: 6.4257
# Epoch 55 | Batch: 1 | Loss: 25.1984
# Epoch 55 | Batch: 2 | Loss: 15.8247
# Epoch 55 | Batch: 3 | Loss: 15.4569
# Epoch 55 | Batch: 4 | Loss: 17.9426
# Epoch 55 | Batch: 5 | Loss: 15.2295
# Epoch 55 | Batch: 6 | Loss: 17.2822
# Epoch 55 | Batch: 7 | Loss: 14.9704
# Epoch 55 | Batch: 8 | Loss: 13.7165
# Epoch 55 | Batch: 9 | Loss: 15.6440
# Epoch 55 | Batch: 10 | Loss: 22.9395
# Epoch 55 | Batch: 11 | Loss: 16.5776
# Epoch 55 | Batch: 12 | Loss: 14.3687
# Epoch 55 | Batch: 13 | Loss: 13.6377
# Epoch 55 | Batch: 14 | Loss: 17.3617
# Epoch 55 | Batch: 15 | Loss: 17.3826
# Epoch 55 | Batch: 16 | Loss: 12.7857
# Epoch 55 | Batch: 17 | Loss: 11.1618
# Epoch 55 | Batch: 18 | Loss: 17.2547
# Epoch 55 | Batch: 19 | Loss: 10.3449
# Epoch 55 | Batch: 20 | Loss: 18.3603
# Epoch 55 | Batch: 21 | Loss: 13.4478
# ...
# Epoch 183 | Batch: 7 | Loss: 18.0757
# Epoch 183 | Batch: 8 | Loss: 10.7687
# Epoch 183 | Batch: 9 | Loss: 11.9957
# Epoch 183 | Batch: 10 | Loss: 12.7095
# Epoch 183 | Batch: 11 | Loss: 17.6136
# Epoch 183 | Batch: 12 | Loss: 17.5092
# Epoch 183 | Batch: 13 | Loss: 16.3609
# Epoch 183 | Batch: 14 | Loss: 17.8688
# Epoch 183 | Batch: 15 | Loss: 16.7225
# Epoch 183 | Batch: 16 | Loss: 14.4057
# Epoch 183 | Batch: 17 | Loss: 15.4742
# Epoch 183 | Batch: 18 | Loss: 12.7088
# Epoch 183 | Batch: 19 | Loss: 8.1494
# Epoch 183 | Batch: 20 | Loss: 11.0112
# Epoch 183 | Batch: 21 | Loss: 14.8646
# Epoch 183 | Batch: 22 | Loss: 11.5321
# Epoch 183 | Batch: 23 | Loss: 22.8857
# Epoch 183 | Batch: 24 | Loss: 10.1493
# Epoch 184 | Batch: 1 | Loss: 15.3750
# Epoch 184 | Batch: 2 | Loss: 17.5298
# Epoch 184 | Batch: 3 | Loss: 18.9155
# Epoch 184 | Batch: 4 | Loss: 16.0537
# Epoch 184 | Batch: 5 | Loss: 15.8549
# Epoch 184 | Batch: 6 | Loss: 11.6203
# Epoch 184 | Batch: 7 | Loss: 12.5955
# Epoch 184 | Batch: 8 | Loss: 15.9760
# Epoch 184 | Batch: 9 | Loss: 14.8235
# Epoch 184 | Batch: 10 | Loss: 9.5866
# Epoch 184 | Batch: 11 | Loss: 21.9697
# Epoch 184 | Batch: 12 | Loss: 14.2241
# Epoch 184 | Batch: 13 | Loss: 17.6391
# Epoch 184 | Batch: 14 | Loss: 14.1043
# Epoch 184 | Batch: 15 | Loss: 11.9855
# Epoch 184 | Batch: 16 | Loss: 20.1740
# Epoch 184 | Batch: 17 | Loss: 8.5729
# Epoch 184 | Batch: 18 | Loss: 13.6784
# Epoch 184 | Batch: 19 | Loss: 9.6097
# Epoch 184 | Batch: 20 | Loss: 9.5428
# Epoch 184 | Batch: 21 | Loss: 9.3359
# Epoch 184 | Batch: 22 | Loss: 15.9182
# Epoch 184 | Batch: 23 | Loss: 11.2356
# Epoch 184 | Batch: 24 | Loss: 8.2351
# Epoch 185 | Batch: 1 | Loss: 12.1999
# Epoch 185 | Batch: 2 | Loss: 12.5113
# Epoch 185 | Batch: 3 | Loss: 10.9930
# Epoch 185 | Batch: 4 | Loss: 19.8481
# Epoch 185 | Batch: 5 | Loss: 14.1582
# Epoch 185 | Batch: 6 | Loss: 16.0414
# Epoch 185 | Batch: 7 | Loss: 16.6755
# Epoch 185 | Batch: 8 | Loss: 16.0415
# Epoch 185 | Batch: 9 | Loss: 18.7812
# Epoch 185 | Batch: 10 | Loss: 12.9893
# Epoch 185 | Batch: 11 | Loss: 11.7238
# Epoch 185 | Batch: 12 | Loss: 10.9695
# Epoch 185 | Batch: 13 | Loss: 14.3946
# Epoch 185 | Batch: 14 | Loss: 12.2903
# Epoch 185 | Batch: 15 | Loss: 14.2964
# Epoch 185 | Batch: 16 | Loss: 14.2887
# Epoch 185 | Batch: 17 | Loss: 14.5331
# Epoch 185 | Batch: 18 | Loss: 11.3313
# Epoch 185 | Batch: 19 | Loss: 8.3609
# Epoch 185 | Batch: 20 | Loss: 15.9901
# Epoch 185 | Batch: 21 | Loss: 16.2073
# Epoch 185 | Batch: 22 | Loss: 18.5209
# Epoch 185 | Batch: 23 | Loss: 17.7309
# Epoch 185 | Batch: 24 | Loss: 8.1052
# Epoch 186 | Batch: 1 | Loss: 12.8262
# Epoch 186 | Batch: 2 | Loss: 13.5704
# Epoch 186 | Batch: 3 | Loss: 14.2342
# Epoch 186 | Batch: 4 | Loss: 11.6423
# Epoch 186 | Batch: 5 | Loss: 14.0113
# Epoch 186 | Batch: 6 | Loss: 12.4255
# Epoch 186 | Batch: 7 | Loss: 14.2632
# Epoch 186 | Batch: 8 | Loss: 15.3574
# Epoch 186 | Batch: 9 | Loss: 10.2092
# Epoch 186 | Batch: 10 | Loss: 18.1854
# Epoch 186 | Batch: 11 | Loss: 18.1414
# Epoch 186 | Batch: 12 | Loss: 17.2891
# Epoch 186 | Batch: 13 | Loss: 20.4487
# Epoch 186 | Batch: 14 | Loss: 11.2115
# Epoch 186 | Batch: 15 | Loss: 11.0899
# Epoch 186 | Batch: 16 | Loss: 13.5499
# Epoch 186 | Batch: 17 | Loss: 15.8173
# Epoch 186 | Batch: 18 | Loss: 13.3972
# Epoch 186 | Batch: 19 | Loss: 12.7437
# Epoch 186 | Batch: 20 | Loss: 9.9731
# Epoch 186 | Batch: 21 | Loss: 13.2586
# Epoch 186 | Batch: 22 | Loss: 14.8423
# Epoch 186 | Batch: 23 | Loss: 13.7764
# Epoch 186 | Batch: 24 | Loss: 7.2101
# Epoch 187 | Batch: 1 | Loss: 11.9779
# Epoch 187 | Batch: 2 | Loss: 15.9008
# Epoch 187 | Batch: 3 | Loss: 20.3775
# Epoch 187 | Batch: 4 | Loss: 12.5326
# Epoch 187 | Batch: 5 | Loss: 16.5420
# Epoch 187 | Batch: 6 | Loss: 9.2862
# Epoch 187 | Batch: 7 | Loss: 14.3788
# Epoch 187 | Batch: 8 | Loss: 15.4959
# Epoch 187 | Batch: 9 | Loss: 11.9979
# Epoch 187 | Batch: 10 | Loss: 14.7517
# Epoch 187 | Batch: 11 | Loss: 15.4450
# Epoch 187 | Batch: 12 | Loss: 13.7347
# Epoch 187 | Batch: 13 | Loss: 13.7853
# Epoch 187 | Batch: 14 | Loss: 13.9045
# Epoch 187 | Batch: 15 | Loss: 14.6535
# Epoch 187 | Batch: 16 | Loss: 15.6073
# Epoch 187 | Batch: 17 | Loss: 9.5681
# Epoch 187 | Batch: 18 | Loss: 11.4777
# Epoch 187 | Batch: 19 | Loss: 14.7192
# Epoch 187 | Batch: 20 | Loss: 11.4665
# Epoch 187 | Batch: 21 | Loss: 23.8516
# Epoch 187 | Batch: 22 | Loss: 11.8023
# Epoch 187 | Batch: 23 | Loss: 16.2538
# Epoch 187 | Batch: 24 | Loss: 10.0437
# Epoch 188 | Batch: 1 | Loss: 15.7707
# Epoch 188 | Batch: 2 | Loss: 20.8310
# Epoch 188 | Batch: 3 | Loss: 12.1189
# Epoch 188 | Batch: 4 | Loss: 16.3548
# Epoch 188 | Batch: 5 | Loss: 16.4110
# Epoch 188 | Batch: 6 | Loss: 15.9812
# Epoch 188 | Batch: 7 | Loss: 11.2436
# Epoch 188 | Batch: 8 | Loss: 11.1010
# Epoch 188 | Batch: 9 | Loss: 9.4730
# Epoch 188 | Batch: 10 | Loss: 10.3707
# Epoch 188 | Batch: 11 | Loss: 10.9795
# Epoch 188 | Batch: 12 | Loss: 14.6170
# Epoch 188 | Batch: 13 | Loss: 18.0441
# Epoch 188 | Batch: 14 | Loss: 12.3826
# Epoch 188 | Batch: 15 | Loss: 12.6884
# Epoch 188 | Batch: 16 | Loss: 12.6082
# Epoch 188 | Batch: 17 | Loss: 10.6674
# Epoch 188 | Batch: 18 | Loss: 9.8534
# Epoch 188 | Batch: 19 | Loss: 21.6587
# Epoch 188 | Batch: 20 | Loss: 18.6695
# Epoch 188 | Batch: 21 | Loss: 18.3346
# Epoch 188 | Batch: 22 | Loss: 14.6926
# Epoch 188 | Batch: 23 | Loss: 12.4183
# Epoch 188 | Batch: 24 | Loss: 11.0886
# Epoch 189 | Batch: 1 | Loss: 20.6953
# Epoch 189 | Batch: 2 | Loss: 18.1352
# Epoch 189 | Batch: 3 | Loss: 14.1077
# Epoch 189 | Batch: 4 | Loss: 12.2291
# Epoch 189 | Batch: 5 | Loss: 10.8462
# Epoch 189 | Batch: 6 | Loss: 9.4534
# Epoch 189 | Batch: 7 | Loss: 9.1850
# Epoch 189 | Batch: 8 | Loss: 11.3195
# Epoch 189 | Batch: 9 | Loss: 12.4953
# Epoch 189 | Batch: 10 | Loss: 16.3877
# Epoch 189 | Batch: 11 | Loss: 14.5116
# Epoch 189 | Batch: 12 | Loss: 11.4958
# Epoch 189 | Batch: 13 | Loss: 12.8394
# Epoch 189 | Batch: 14 | Loss: 16.9624
# Epoch 189 | Batch: 15 | Loss: 9.5561
# Epoch 189 | Batch: 16 | Loss: 16.3055
# Epoch 189 | Batch: 17 | Loss: 12.3084
# Epoch 189 | Batch: 18 | Loss: 15.2616
# Epoch 189 | Batch: 19 | Loss: 17.5344
# Epoch 189 | Batch: 20 | Loss: 14.1501
# Epoch 189 | Batch: 21 | Loss: 11.6950
# Epoch 189 | Batch: 22 | Loss: 12.7341
# Epoch 189 | Batch: 23 | Loss: 17.1861
# Epoch 189 | Batch: 24 | Loss: 9.7059
# Epoch 190 | Batch: 1 | Loss: 16.7811
# Epoch 190 | Batch: 2 | Loss: 10.3236
# Epoch 190 | Batch: 3 | Loss: 11.6709
# Epoch 190 | Batch: 4 | Loss: 18.5861
# Epoch 190 | Batch: 5 | Loss: 20.9336
# Epoch 190 | Batch: 6 | Loss: 17.9699
# Epoch 190 | Batch: 7 | Loss: 16.7540
# Epoch 190 | Batch: 8 | Loss: 16.0239
# Epoch 190 | Batch: 9 | Loss: 18.9023
# Epoch 190 | Batch: 10 | Loss: 11.9280
# Epoch 190 | Batch: 11 | Loss: 11.1696
# Epoch 190 | Batch: 12 | Loss: 13.0375
# Epoch 190 | Batch: 13 | Loss: 10.9236
# Epoch 190 | Batch: 14 | Loss: 12.9240
# Epoch 190 | Batch: 15 | Loss: 16.4282
# Epoch 190 | Batch: 16 | Loss: 14.3663
# Epoch 190 | Batch: 17 | Loss: 21.4341
# Epoch 190 | Batch: 18 | Loss: 15.8003
# Epoch 190 | Batch: 19 | Loss: 21.1339
# Epoch 190 | Batch: 20 | Loss: 14.1342
# Epoch 190 | Batch: 21 | Loss: 10.2494
# Epoch 190 | Batch: 22 | Loss: 8.3434
# Epoch 190 | Batch: 23 | Loss: 11.9660
# Epoch 190 | Batch: 24 | Loss: 10.4950
# Epoch 191 | Batch: 1 | Loss: 9.5204
# Epoch 191 | Batch: 2 | Loss: 12.3327
# Epoch 191 | Batch: 3 | Loss: 14.3110
# Epoch 191 | Batch: 4 | Loss: 12.1628
# Epoch 191 | Batch: 5 | Loss: 16.1804
# Epoch 191 | Batch: 6 | Loss: 13.2210
# Epoch 191 | Batch: 7 | Loss: 11.2164
# Epoch 191 | Batch: 8 | Loss: 10.6238
# Epoch 191 | Batch: 9 | Loss: 14.2219
# Epoch 191 | Batch: 10 | Loss: 8.8362
# Epoch 191 | Batch: 11 | Loss: 17.4772
# Epoch 191 | Batch: 12 | Loss: 13.9506
# Epoch 191 | Batch: 13 | Loss: 17.2676
# Epoch 191 | Batch: 14 | Loss: 19.2524
# Epoch 191 | Batch: 15 | Loss: 17.2245
# Epoch 191 | Batch: 16 | Loss: 20.7647
# Epoch 191 | Batch: 17 | Loss: 15.7329
# Epoch 191 | Batch: 18 | Loss: 14.0679
# Epoch 191 | Batch: 19 | Loss: 25.0434
# Epoch 191 | Batch: 20 | Loss: 11.9040
# Epoch 191 | Batch: 21 | Loss: 15.5963
# Epoch 191 | Batch: 22 | Loss: 14.1506
# Epoch 191 | Batch: 23 | Loss: 11.8704
# Epoch 191 | Batch: 24 | Loss: 7.6485
# Epoch 192 | Batch: 1 | Loss: 14.5372
# Epoch 192 | Batch: 2 | Loss: 9.1620
# Epoch 192 | Batch: 3 | Loss: 14.0638
# Epoch 192 | Batch: 4 | Loss: 19.6351
# Epoch 192 | Batch: 5 | Loss: 16.7873
# Epoch 192 | Batch: 6 | Loss: 14.4294
# Epoch 192 | Batch: 7 | Loss: 12.1239
# Epoch 192 | Batch: 8 | Loss: 9.3086
# Epoch 192 | Batch: 9 | Loss: 18.4285
# Epoch 192 | Batch: 10 | Loss: 15.1683
# Epoch 192 | Batch: 11 | Loss: 14.1052
# Epoch 192 | Batch: 12 | Loss: 17.4231
# Epoch 192 | Batch: 13 | Loss: 15.1864
# Epoch 192 | Batch: 14 | Loss: 14.1943
# Epoch 192 | Batch: 15 | Loss: 12.5766
# Epoch 192 | Batch: 16 | Loss: 12.0860
# Epoch 192 | Batch: 17 | Loss: 11.8313
# Epoch 192 | Batch: 18 | Loss: 12.9751
# Epoch 192 | Batch: 19 | Loss: 11.1001
# Epoch 192 | Batch: 20 | Loss: 15.4247
# Epoch 192 | Batch: 21 | Loss: 21.0695
# Epoch 192 | Batch: 22 | Loss: 14.7658
# Epoch 192 | Batch: 23 | Loss: 13.8475
# Epoch 192 | Batch: 24 | Loss: 11.1088
# Epoch 193 | Batch: 1 | Loss: 14.3395
# Epoch 193 | Batch: 2 | Loss: 16.3417
# Epoch 193 | Batch: 3 | Loss: 13.1150
# Epoch 193 | Batch: 4 | Loss: 16.2084
# Epoch 193 | Batch: 5 | Loss: 27.6475
# Epoch 193 | Batch: 6 | Loss: 16.2291
# Epoch 193 | Batch: 7 | Loss: 13.0873
# Epoch 193 | Batch: 8 | Loss: 13.8334
# Epoch 193 | Batch: 9 | Loss: 15.6410
# Epoch 193 | Batch: 10 | Loss: 11.3272
# Epoch 193 | Batch: 11 | Loss: 14.6083
# Epoch 193 | Batch: 12 | Loss: 14.8243
# Epoch 193 | Batch: 13 | Loss: 9.5182
# Epoch 193 | Batch: 14 | Loss: 9.7280
# Epoch 193 | Batch: 15 | Loss: 12.7458
# Epoch 193 | Batch: 16 | Loss: 15.8186
# Epoch 193 | Batch: 17 | Loss: 15.0198
# Epoch 193 | Batch: 18 | Loss: 12.5142
# Epoch 193 | Batch: 19 | Loss: 10.2053
# Epoch 193 | Batch: 20 | Loss: 12.9755
# Epoch 193 | Batch: 21 | Loss: 12.2677
# Epoch 193 | Batch: 22 | Loss: 20.0373
# Epoch 193 | Batch: 23 | Loss: 14.2541
# Epoch 193 | Batch: 24 | Loss: 13.9396
# Epoch 194 | Batch: 1 | Loss: 9.7093
# Epoch 194 | Batch: 2 | Loss: 15.2232
# Epoch 194 | Batch: 3 | Loss: 14.8211
# Epoch 194 | Batch: 4 | Loss: 12.6618
# Epoch 194 | Batch: 5 | Loss: 19.0018
# Epoch 194 | Batch: 6 | Loss: 15.7726
# Epoch 194 | Batch: 7 | Loss: 15.3456
# Epoch 194 | Batch: 8 | Loss: 22.5856
# Epoch 194 | Batch: 9 | Loss: 12.4282
# Epoch 194 | Batch: 10 | Loss: 20.3791
# Epoch 194 | Batch: 11 | Loss: 10.3160
# Epoch 194 | Batch: 12 | Loss: 17.1132
# Epoch 194 | Batch: 13 | Loss: 14.8038
# Epoch 194 | Batch: 14 | Loss: 14.9961
# Epoch 194 | Batch: 15 | Loss: 17.5889
# Epoch 194 | Batch: 16 | Loss: 10.1780
# Epoch 194 | Batch: 17 | Loss: 9.9864
# Epoch 194 | Batch: 18 | Loss: 9.9232
# Epoch 194 | Batch: 19 | Loss: 13.2855
# Epoch 194 | Batch: 20 | Loss: 13.4924
# Epoch 194 | Batch: 21 | Loss: 13.6707
# Epoch 194 | Batch: 22 | Loss: 16.2538
# Epoch 194 | Batch: 23 | Loss: 18.8334
# Epoch 194 | Batch: 24 | Loss: 8.9672
# Epoch 195 | Batch: 1 | Loss: 12.3132
# Epoch 195 | Batch: 2 | Loss: 11.2340
# Epoch 195 | Batch: 3 | Loss: 16.3743
# Epoch 195 | Batch: 4 | Loss: 13.9287
# Epoch 195 | Batch: 5 | Loss: 11.9864
# Epoch 195 | Batch: 6 | Loss: 15.0165
# Epoch 195 | Batch: 7 | Loss: 13.9879
# Epoch 195 | Batch: 8 | Loss: 12.8114
# Epoch 195 | Batch: 9 | Loss: 11.0142
# Epoch 195 | Batch: 10 | Loss: 14.0238
# Epoch 195 | Batch: 11 | Loss: 15.4873
# Epoch 195 | Batch: 12 | Loss: 10.7550
# Epoch 195 | Batch: 13 | Loss: 12.5660
# Epoch 195 | Batch: 14 | Loss: 11.7442
# Epoch 195 | Batch: 15 | Loss: 10.6123
# Epoch 195 | Batch: 16 | Loss: 20.2896
# Epoch 195 | Batch: 17 | Loss: 15.6087
# Epoch 195 | Batch: 18 | Loss: 20.2026
# Epoch 195 | Batch: 19 | Loss: 14.0273
# Epoch 195 | Batch: 20 | Loss: 12.6799
# Epoch 195 | Batch: 21 | Loss: 16.1980
# Epoch 195 | Batch: 22 | Loss: 11.8293
# Epoch 195 | Batch: 23 | Loss: 16.3104
# Epoch 195 | Batch: 24 | Loss: 10.6553
# Epoch 196 | Batch: 1 | Loss: 17.2966
# Epoch 196 | Batch: 2 | Loss: 16.1027
# Epoch 196 | Batch: 3 | Loss: 12.1291
# Epoch 196 | Batch: 4 | Loss: 11.2234
# Epoch 196 | Batch: 5 | Loss: 12.8426
# Epoch 196 | Batch: 6 | Loss: 11.1280
# Epoch 196 | Batch: 7 | Loss: 17.0370
# Epoch 196 | Batch: 8 | Loss: 17.9671
# Epoch 196 | Batch: 9 | Loss: 19.1225
# Epoch 196 | Batch: 10 | Loss: 12.1884
# Epoch 196 | Batch: 11 | Loss: 26.6374
# Epoch 196 | Batch: 12 | Loss: 13.1768
# Epoch 196 | Batch: 13 | Loss: 12.3044
# Epoch 196 | Batch: 14 | Loss: 11.1275
# Epoch 196 | Batch: 15 | Loss: 11.2057
# Epoch 196 | Batch: 16 | Loss: 11.4639
# Epoch 196 | Batch: 17 | Loss: 11.6438
# Epoch 196 | Batch: 18 | Loss: 15.6001
# Epoch 196 | Batch: 19 | Loss: 16.6163
# Epoch 196 | Batch: 20 | Loss: 10.7000
# Epoch 196 | Batch: 21 | Loss: 15.9751
# Epoch 196 | Batch: 22 | Loss: 16.7017
# Epoch 196 | Batch: 23 | Loss: 12.8337
# Epoch 196 | Batch: 24 | Loss: 8.4710
# Epoch 197 | Batch: 1 | Loss: 19.8469
# Epoch 197 | Batch: 2 | Loss: 14.5642
# Epoch 197 | Batch: 3 | Loss: 13.4068
# Epoch 197 | Batch: 4 | Loss: 15.6918
# Epoch 197 | Batch: 5 | Loss: 14.3883
# Epoch 197 | Batch: 6 | Loss: 11.7318
# Epoch 197 | Batch: 7 | Loss: 9.3973
# Epoch 197 | Batch: 8 | Loss: 14.0375
# Epoch 197 | Batch: 9 | Loss: 18.3204
# Epoch 197 | Batch: 10 | Loss: 14.8779
# Epoch 197 | Batch: 11 | Loss: 9.1817
# Epoch 197 | Batch: 12 | Loss: 12.2216
# Epoch 197 | Batch: 13 | Loss: 10.1621
# Epoch 197 | Batch: 14 | Loss: 12.3904
# Epoch 197 | Batch: 15 | Loss: 11.1895
# Epoch 197 | Batch: 16 | Loss: 12.9035
# Epoch 197 | Batch: 17 | Loss: 15.7521
# Epoch 197 | Batch: 18 | Loss: 12.0564
# Epoch 197 | Batch: 19 | Loss: 13.9169
# Epoch 197 | Batch: 20 | Loss: 16.8114
# Epoch 197 | Batch: 21 | Loss: 10.9858
# Epoch 197 | Batch: 22 | Loss: 10.3116
# Epoch 197 | Batch: 23 | Loss: 20.0509
# Epoch 197 | Batch: 24 | Loss: 13.0281
# Epoch 198 | Batch: 1 | Loss: 12.2249
# Epoch 198 | Batch: 2 | Loss: 12.9806
# Epoch 198 | Batch: 3 | Loss: 11.0618
# Epoch 198 | Batch: 4 | Loss: 20.2465
# Epoch 198 | Batch: 5 | Loss: 12.9460
# Epoch 198 | Batch: 6 | Loss: 11.5815
# Epoch 198 | Batch: 7 | Loss: 15.8888
# Epoch 198 | Batch: 8 | Loss: 9.2498
# Epoch 198 | Batch: 9 | Loss: 14.1650
# Epoch 198 | Batch: 10 | Loss: 17.7173
# Epoch 198 | Batch: 11 | Loss: 17.5088
# Epoch 198 | Batch: 12 | Loss: 13.8133
# Epoch 198 | Batch: 13 | Loss: 11.5061
# Epoch 198 | Batch: 14 | Loss: 18.7266
# Epoch 198 | Batch: 15 | Loss: 11.0422
# Epoch 198 | Batch: 16 | Loss: 10.4967
# Epoch 198 | Batch: 17 | Loss: 12.3906
# Epoch 198 | Batch: 18 | Loss: 14.7540
# Epoch 198 | Batch: 19 | Loss: 14.8615
# Epoch 198 | Batch: 20 | Loss: 17.0634
# Epoch 198 | Batch: 21 | Loss: 13.4051
# Epoch 198 | Batch: 22 | Loss: 20.7684
# Epoch 198 | Batch: 23 | Loss: 14.7794
# Epoch 198 | Batch: 24 | Loss: 5.4399
# Epoch 199 | Batch: 1 | Loss: 12.1638
# Epoch 199 | Batch: 2 | Loss: 15.5474
# Epoch 199 | Batch: 3 | Loss: 15.7487
# Epoch 199 | Batch: 4 | Loss: 11.7537
# Epoch 199 | Batch: 5 | Loss: 15.0220
# Epoch 199 | Batch: 6 | Loss: 14.4974
# Epoch 199 | Batch: 7 | Loss: 13.0520
# Epoch 199 | Batch: 8 | Loss: 14.2262
# Epoch 199 | Batch: 9 | Loss: 8.7795
# Epoch 199 | Batch: 10 | Loss: 16.3754
# Epoch 199 | Batch: 11 | Loss: 16.7620
# Epoch 199 | Batch: 12 | Loss: 11.9408
# Epoch 199 | Batch: 13 | Loss: 15.0296
# Epoch 199 | Batch: 14 | Loss: 9.9103
# Epoch 199 | Batch: 15 | Loss: 13.2682
# Epoch 199 | Batch: 16 | Loss: 12.8334
# Epoch 199 | Batch: 17 | Loss: 10.0803
# Epoch 199 | Batch: 18 | Loss: 20.8113
# Epoch 199 | Batch: 19 | Loss: 17.6708
# Epoch 199 | Batch: 20 | Loss: 14.6904
# Epoch 199 | Batch: 21 | Loss: 9.7212
# Epoch 199 | Batch: 22 | Loss: 13.2641
# Epoch 199 | Batch: 23 | Loss: 18.3531
# Epoch 199 | Batch: 24 | Loss: 7.8895
# Epoch 200 | Batch: 1 | Loss: 8.5837
# Epoch 200 | Batch: 2 | Loss: 12.6735
# Epoch 200 | Batch: 3 | Loss: 13.7637
# Epoch 200 | Batch: 4 | Loss: 13.6814
# Epoch 200 | Batch: 5 | Loss: 22.2914
# Epoch 200 | Batch: 6 | Loss: 11.8420
# Epoch 200 | Batch: 7 | Loss: 13.5979
# Epoch 200 | Batch: 8 | Loss: 14.7846
# Epoch 200 | Batch: 9 | Loss: 10.8719
# Epoch 200 | Batch: 10 | Loss: 16.8501
# Epoch 200 | Batch: 11 | Loss: 15.5003
# Epoch 200 | Batch: 12 | Loss: 13.7610
# Epoch 200 | Batch: 13 | Loss: 12.0254
# Epoch 200 | Batch: 14 | Loss: 22.9156
# Epoch 200 | Batch: 15 | Loss: 10.6469
# Epoch 200 | Batch: 16 | Loss: 13.3378
# Epoch 200 | Batch: 17 | Loss: 11.9434
# Epoch 200 | Batch: 18 | Loss: 11.1029
# Epoch 200 | Batch: 19 | Loss: 14.8196
# Epoch 200 | Batch: 20 | Loss: 15.3225
# Epoch 200 | Batch: 21 | Loss: 11.5626
# Epoch 200 | Batch: 22 | Loss: 9.8585
# Epoch 200 | Batch: 23 | Loss: 15.3564
# Epoch 200 | Batch: 24 | Loss: 8.7914
